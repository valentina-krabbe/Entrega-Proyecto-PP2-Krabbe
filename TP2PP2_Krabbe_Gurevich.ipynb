# %%
# @title
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)

# %%
# @title
from IPython.display import HTML

HTML('''
<style>
body {
  background: radial-gradient(circle at bottom, #060606 0%, #000000 80%);
  color: #f5f5f5;
  font-family: 'Poppins', sans-serif;
  letter-spacing: 0.3px;
  overflow-x: hidden;
}

.container {
  max-width: 1000px;
  margin: 50px auto;
  background: linear-gradient(145deg, rgba(20,20,20,0.95), rgba(30,0,30,0.9));
  border-radius: 25px;
  padding: 40px;
  box-shadow: 0 0 30px #00ff9975, 0 0 60px #ff00aa55;
  border: 1px solid rgba(255,255,255,0.1);
  backdrop-filter: blur(8px);
}

h1, h2, h3 {
  text-align: center;
  text-transform: uppercase;
}

h1 {
  font-size: 2.5em;
  background: linear-gradient(90deg, #00ff99, #ff00aa);
  -webkit-background-clip: text;
  color: transparent;
  text-shadow: 0 0 20px #00ff9975, 0 0 40px #ff00aa55;
}

h2 {
  font-size: 1.6em;
  color: #ffb3e6;
  margin-top: -5px;
  text-shadow: 0 0 15px #ff00aa;
}

h3 {
  color: #00ff99;
  margin-top: 25px;
  text-shadow: 0 0 10px #00ff99;
}

.card {
  background: rgba(0,0,0,0.6);
  border: 1px solid #00ff9966;
  border-radius: 20px;
  padding: 25px;
  margin: 25px 0;
  box-shadow: 0 0 25px #00ff9944, 0 0 35px #ff00aa33 inset;
  transition: all 0.3s;
}

.card:hover {
  transform: scale(1.02);
  box-shadow: 0 0 30px #ff00aa55, 0 0 45px #00ff9966 inset;
}

pre {
  background: rgba(10,10,10,0.85);
  color: #00ffcc;
  border-left: 4px solid #ff00aa;
  padding: 10px 15px;
  border-radius: 10px;
  overflow-x: auto;
}

footer {
  text-align: center;
  color: #888;
  margin-top: 40px;
  font-size: 0.9em;
}
</style>
''')
# Out:
# <style>
# body {
#   background: radial-gradient(circle at bottom, #060606 0%, #000000 80%);
#   color: #f5f5f5;
#   font-family: 'Poppins', sans-serif;
#   letter-spacing: 0.3px;
#   overflow-x: hidden;
# }
#
# .container {
#   max-width: 1000px;
#   margin: 50px auto;
#   background: linear-gradient(145deg, rgba(20,20,20,0.95), rgba(30,0,30,0.9));
#   border-radius: 25px;
#   padding: 40px;
#   box-shadow: 0 0 30px #00ff9975, 0 0 60px #ff00aa55;
#   border: 1px solid rgba(255,255,255,0.1);
#   backdrop-filter: blur(8px);
# }
#
# h1, h2, h3 {
#   text-align: center;
#   text-transform: uppercase;
# }
#
# h1 {
#   font-size: 2.5em;
#   background: linear-gradient(90deg, #00ff99, #ff00aa);
#   -webkit-background-clip: text;
#   color: transparent;
#   text-shadow: 0 0 20px #00ff9975, 0 0 40px #ff00aa55;
# }
#
# h2 {
#   font-size: 1.6em;
#   color: #ffb3e6;
#   margin-top: -5px;
#   text-shadow: 0 0 15px #ff00aa;
# }
#
# h3 {
#   color: #00ff99;
#   margin-top: 25px;
#   text-shadow: 0 0 10px #00ff99;
# }
#
# .card {
#   background: rgba(0,0,0,0.6);
#   border: 1px solid #00ff9966;
#   border-radius: 20px;
#   padding: 25px;
#   margin: 25px 0;
#   box-shadow: 0 0 25px #00ff9944, 0 0 35px #ff00aa33 inset;
#   transition: all 0.3s;
# }
#
# .card:hover {
#   transform: scale(1.02);
#   box-shadow: 0 0 30px #ff00aa55, 0 0 45px #00ff9966 inset;
# }
#
# pre {
#   background: rgba(10,10,10,0.85);
#   color: #00ffcc;
#   border-left: 4px solid #ff00aa;
#   padding: 10px 15px;
#   border-radius: 10px;
#   overflow-x: auto;
# }
#
# footer {
#   text-align: center;
#   color: #888;
#   margin-top: 40px;
#   font-size: 0.9em;
# }
# </style>

# %%
# @title
from IPython.display import HTML

HTML('''
<style>
@import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');

body {
  background: radial-gradient(circle at top left, #020202 0%, #080014 40%, #000000 100%);
  color: #f5f5f5;
  font-family: 'Poppins', sans-serif;
  letter-spacing: 0.4px;
  overflow-x: hidden;
}

/* contenedor principal */
.container {
  max-width: 950px;
  margin: 70px auto;
  background: linear-gradient(145deg, rgba(10,10,10,0.95), rgba(25,0,25,0.9));
  border-radius: 30px;
  padding: 50px;
  box-shadow: 0 0 30px #00ff9980, 0 0 60px #ff00aa80;
  border: 1px solid rgba(255,255,255,0.15);
  backdrop-filter: blur(8px);
  animation: pulse 5s infinite alternate; /* Mantenido aquí */
}

/* Títulos con neón */
h1 {
  text-align: center;
  font-size: 2.8em;
  background: linear-gradient(90deg, #00ff99, #ff00aa);
  -webkit-background-clip: text;
  color: transparent;
  text-shadow: 0 0 20px #00ff99aa, 0 0 40px #ff00aaaa;
  font-family: 'Orbitron', sans-serif;
}

h2 {
  text-align: center;
  font-size: 1.6em;
  color: #ffb3e6;
  text-shadow: 0 0 10px #ff00aa;
  margin-top: -10px;
}

.card {
  background: rgba(0,0,0,0.6);
  border: 1px solid #00ff9970;
  border-radius: 20px;
  padding: 25px;
  margin: 30px auto;
  box-shadow: 0 0 25px #00ff9960 inset, 0 0 30px #ff00aa40;
  transition: 0.3s;
  text-align: center;
}

.card:hover {
  transform: scale(1.02);
  box-shadow: 0 0 40px #ff00aa80, 0 0 50px #00ff9980 inset;
}

/* texto */
p, b {
  font-size: 1.05em;
}

.highlight {
  color: #00ffcc;
  text-shadow: 0 0 10px #00ffcc;
}

.name1 {
  color: #00ff99;
  text-shadow: 0 0 10px #00ff99;
}

.name2 {
  color: #ff00aa;
  text-shadow: 0 0 10px #ff00aa;
}

/* párrafo de descripción */
.description {
  margin-top: 40px;
  padding: 0 20px;
  text-align: justify;
  line-height: 1.6;
  border-left: 5px solid #00ff99;
  background: rgba(0,0,0,0.4);
  padding: 20px;
  border-radius: 10px;
}
.description b {
  color: #00ffcc;
  text-shadow: none;
}


/* animación fondo pulsante */
@keyframes pulse {
  0% { box-shadow: 0 0 20px #00ff9966, 0 0 30px #ff00aa66; }
  50% { box-shadow: 0 0 40px #00ff99aa, 0 0 70px #ff00aaaa; }
  100% { box-shadow: 0 0 20px #00ff9966, 0 0 30px #ff00aa66; }
}
</style>

<div class="container">
  <h1>Primer Parcial de PP2 👩‍💻📊</h1>
  <h2>¿Qué variables impactan en la pérdida de talento en las organizaciones? 🤔</h2>

  <div class="card">
    <p><b class="highlight">Integrantes:</b></p>
    <p>💚 <b class="name1">Valentina Krabbe</b> — DNI 45207992</p>
    <p>💖 <b class="name2">Melisa Gurevich</b> — DNI 35365884</p>
  </div>

  <p class="description">
    En este proyecto analizaremos un dataset elaborado por un analista de Recursos Humanos, el cual recopila información de empleados actuales y antiguos (<b>35 variables en total</b>). El objetivo es identificar y comprender los factores que influyen en la rotación y abandono de personal dentro de la empresa.
  </p>
</div>
''')
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');
#
# body {
#   background: radial-gradient(circle at top left, #020202 0%, #080014 40%, #000000 100%);
#   color: #f5f5f5;
#   font-family: 'Poppins', sans-serif;
#   letter-spacing: 0.4px;
#   overflow-x: hidden;
# }
#
# /* contenedor principal */
# .container {
#   max-width: 950px;
#   margin: 70px auto;
#   background: linear-gradient(145deg, rgba(10,10,10,0.95), rgba(25,0,25,0.9));
#   border-radius: 30px;
#   padding: 50px;
#   box-shadow: 0 0 30px #00ff9980, 0 0 60px #ff00aa80;
#   border: 1px solid rgba(255,255,255,0.15);
#   backdrop-filter: blur(8px);
#   animation: pulse 5s infinite alternate; /* Mantenido aquí */
# }
#
# /* Títulos con neón */
# h1 {
#   text-align: center;
#   font-size: 2.8em;
#   background: linear-gradient(90deg, #00ff99, #ff00aa);
#   -webkit-background-clip: text;
#   color: transparent;
#   text-shadow: 0 0 20px #00ff99aa, 0 0 40px #ff00aaaa;
#   font-family: 'Orbitron', sans-serif;
# }
#
# h2 {
#   text-align: center;
#   font-size: 1.6em;
#   color: #ffb3e6;
#   text-shadow: 0 0 10px #ff00aa;
#   margin-top: -10px;
# }
#
# .card {
#   background: rgba(0,0,0,0.6);
#   border: 1px solid #00ff9970;
#   border-radius: 20px;
#   padding: 25px;
#   margin: 30px auto;
#   box-shadow: 0 0 25px #00ff9960 inset, 0 0 30px #ff00aa40;
#   transition: 0.3s;
#   text-align: center;
# }
#
# .card:hover {
#   transform: scale(1.02);
#   box-shadow: 0 0 40px #ff00aa80, 0 0 50px #00ff9980 inset;
# }
#
# /* texto */
# p, b {
#   font-size: 1.05em;
# }
#
# .highlight {
#   color: #00ffcc;
#   text-shadow: 0 0 10px #00ffcc;
# }
#
# .name1 {
#   color: #00ff99;
#   text-shadow: 0 0 10px #00ff99;
# }
#
# .name2 {
#   color: #ff00aa;
#   text-shadow: 0 0 10px #ff00aa;
# }
#
# /* párrafo de descripción */
# .description {
#   margin-top: 40px;
#   padding: 0 20px;
#   text-align: justify;
#   line-height: 1.6;
#   border-left: 5px solid #00ff99;
#   background: rgba(0,0,0,0.4);
#   padding: 20px;
#   border-radius: 10px;
# }
# .description b {
#   color: #00ffcc;
#   text-shadow: none;
# }
#
#
# /* animación fondo pulsante */
# @keyframes pulse {
#   0% { box-shadow: 0 0 20px #00ff9966, 0 0 30px #ff00aa66; }
#   50% { box-shadow: 0 0 40px #00ff99aa, 0 0 70px #ff00aaaa; }
#   100% { box-shadow: 0 0 20px #00ff9966, 0 0 30px #ff00aa66; }
# }
# </style>
#
# <div class="container">
#   <h1>Primer Parcial de PP2 👩‍💻📊</h1>
#   <h2>¿Qué variables impactan en la pérdida de talento en las organizaciones? 🤔</h2>
#
#   <div class="card">
#     <p><b class="highlight">Integrantes:</b></p>
#     <p>💚 <b class="name1">Valentina Krabbe</b> — DNI 45207992</p>
#     <p>💖 <b class="name2">Melisa Gurevich</b> — DNI 35365884</p>
#   </div>
#
#   <p class="description">
#     En este proyecto analizaremos un dataset elaborado por un analista de Recursos Humanos, el cual recopila información de empleados actuales y antiguos (<b>35 variables en total</b>). El objetivo es identificar y comprender los factores que influyen en la rotación y abandono de personal dentro de la empresa.
#   </p>
# </div>

# %% [markdown]
# ### Importación de librerias y herramientas

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve, roc_auc_score, accuracy_score, classification_report, roc_curve
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE               #El algoritmo de sobremuestreo
from imblearn.pipeline import Pipeline as ImbPipeline  #Permite usar SMOTE dentro del Pipeline
from sklearn.preprocessing import FunctionTransformer  #Para Naive Bayes
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report
from IPython.display import display, HTML

# %% [markdown]
# ### Importamos el dataset alojado en GitHub

# %%
url="https://raw.githubusercontent.com/valentina-krabbe/Practicamos-Profesionales-2/refs/heads/main/empleadosRRHH.csv"

df=pd.read_csv(url)

print(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# - Se compone de 35 variables relacionadas con empleados, como edad, viajes, departamento, satisfacción y años en la empresa.
#
# - Vemos un ejemplo de las primeras filas para conocer su estructura.
#
# - Presencia de muchas variables distintas para analizar la rotación.

# %% [markdown]
# ###Cambiamos en la columna "Rotacion" las variables Yes y No por 1 y 0

# %%
df["Attrition"] = df["Attrition"].replace({"Yes": 1, "No": 0}).astype(int)
# Out:
# /tmp/ipython-input-2931871255.py:1: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %% [markdown]
# ### Modificamos los nombres de las columnas

# %%
# Diccionario: columna_original : "nuevo_nombre"
nuevos_nombres = {
    "Age": "Edad",
    "Attrition": "Rotacion",
    "BusinessTravel": "Viajes_Negocios",
    "DailyRate": "Salario_Diario",
    "Department": "Departamento",
    "DistanceFromHome": "Distancia_Hogar",
    "Education": "Nivel_Educativo",
    "EducationField": "Area_Educacion",
    "EmployeeCount": "Conteo_Empleados",
    "EmployeeNumber": "Numero_Empleado",
    "EnvironmentSatisfaction": "Satisfaccion_Entorno",
    "Gender": "Genero",
    "HourlyRate": "Salario_Hora",
    "JobInvolvement": "Compromiso_Trabajo",
    "JobLevel": "Nivel_Puesto",
    "JobRole": "Rol_Laboral",
    "JobSatisfaction": "Satisfaccion_Trabajo",
    "MaritalStatus": "Estado_Civil",
    "MonthlyIncome": "Ingreso_Mensual",
    "MonthlyRate": "Salario_Mensual",
    "NumCompaniesWorked": "Empresas_Trabajadas",
    "Over18": "Mayor_18",
    "OverTime": "Horas_Extra",
    "PercentSalaryHike": "Aumento_Salarial_Porc",
    "PerformanceRating": "Calificacion_Desempeno",
    "RelationshipSatisfaction": "Satisfaccion_Relaciones",
    "StandardHours": "Horas_Estandar",
    "StockOptionLevel": "Nivel_Acciones",
    "TotalWorkingYears": "Anios_Experiencia_Total",
    "TrainingTimesLastYear": "Capacitaciones_Ultimo_Anio",
    "WorkLifeBalance": "Balance_Vida_Trabajo",
    "YearsAtCompany": "Anios_Empresa",
    "YearsInCurrentRole": "Anios_Puesto_Actual",
    "YearsSinceLastPromotion": "Anios_Desde_Promocion",
    "YearsWithCurrManager": "Anios_Con_Jefe"
}

# %%
df=df.rename(columns=nuevos_nombres)

print(df.head())
# Out:
#    Edad  Rotacion    Viajes_Negocios  Salario_Diario            Departamento  \
# 0    41         1      Travel_Rarely            1102                   Sales
# 1    49         0  Travel_Frequently             279  Research & Development
# 2    37         1      Travel_Rarely            1373  Research & Development
# 3    33         0  Travel_Frequently            1392  Research & Development
# 4    27         0      Travel_Rarely             591  Research & Development
#
#    Distancia_Hogar  Nivel_Educativo Area_Educacion  Conteo_Empleados  \
# 0                1                2  Life Sciences                 1
# 1                8                1  Life Sciences                 1
# 2                2                2          Other                 1
# 3                3                4  Life Sciences                 1
# 4                2                1        Medical                 1
#
#    Numero_Empleado  ...  Satisfaccion_Relaciones Horas_Estandar  \
# 0                1  ...                        1             80
# 1                2  ...                        4             80
# 2                4  ...                        2             80
# 3                5  ...                        3             80
# 4                7  ...                        4             80
#
#    Nivel_Acciones  Anios_Experiencia_Total  Capacitaciones_Ultimo_Anio  \
# 0               0                        8                           0
# 1               1                       10                           3
# 2               0                        7                           3
# 3               0                        8                           3
# 4               1                        6                           3
#
#   Balance_Vida_Trabajo  Anios_Empresa Anios_Puesto_Actual  \
# 0                    1              6                   4
# 1                    3             10                   7
# 2                    3              0                   0
# 3                    3              8                   7
# 4                    3              2                   2
#
#    Anios_Desde_Promocion  Anios_Con_Jefe
# 0                      0               5
# 1                      1               7
# 2                      0               0
# 3                      3               0
# 4                      2               2
#
# [5 rows x 35 columns]

# %% [markdown]
# - Primero convertimos la variable Rotación de texto (‘Yes’/‘No’) a valores numéricos 1 y 0, para que el modelo pueda trabajar con ella.
#
# - Después renombramos las columnas con nombres más claros en español, como Edad, Ingreso Mensual, Satisfacción en el Trabajo, etc.
#
# - Esto facilita la interpretación de los resultados y que los gráficos sean más entendibles.
#
# - Con el dataset limpio y en español, ya podemos empezar a analizar las variables y entrenar nuestro modelo.

# %% [markdown]
# ## Procesamiento y Exploración de datos

# %% [markdown]
# Verificación de nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Edad                        1470 non-null   int64
#  1   Rotacion                    1470 non-null   int64
#  2   Viajes_Negocios             1470 non-null   object
#  3   Salario_Diario              1470 non-null   int64
#  4   Departamento                1470 non-null   object
#  5   Distancia_Hogar             1470 non-null   int64
#  6   Nivel_Educativo             1470 non-null   int64
#  7   Area_Educacion              1470 non-null   object
#  8   Conteo_Empleados            1470 non-null   int64
#  9   Numero_Empleado             1470 non-null   int64
#  10  Satisfaccion_Entorno        1470 non-null   int64
#  11  Genero                      1470 non-null   object
#  12  Salario_Hora                1470 non-null   int64
#  13  Compromiso_Trabajo          1470 non-null   int64
#  14  Nivel_Puesto                1470 non-null   int64
#  15  Rol_Laboral                 1470 non-null   object
#  16  Satisfaccion_Trabajo        1470 non-null   int64
#  17  Estado_Civil                1470 non-null   object
#  18  Ingreso_Mensual             1470 non-null   int64
#  19  Salario_Mensual             1470 non-null   int64
#  20  Empresas_Trabajadas         1470 non-null   int64
#  21  Mayor_18                    1470 non-null   object
#  22  Horas_Extra                 1470 non-null   object
#  23  Aumento_Salarial_Porc       1470 non-null   int64
#  24  Calificacion_Desempeno      1470 non-null   int64
#  25  Satisfaccion_Relaciones     1470 non-null   int64
#  26  Horas_Estandar              1470 non-null   int64
#  27  Nivel_Acciones              1470 non-null   int64
#  28  Anios_Experiencia_Total     1470 non-null   int64
#  29  Capacitaciones_Ultimo_Anio  1470 non-null   int64
#  30  Balance_Vida_Trabajo        1470 non-null   int64
#  31  Anios_Empresa               1470 non-null   int64
#  32  Anios_Puesto_Actual         1470 non-null   int64
#  33  Anios_Desde_Promocion       1470 non-null   int64
#  34  Anios_Con_Jefe              1470 non-null   int64
# dtypes: int64(27), object(8)
# memory usage: 402.1+ KB

# %% [markdown]
# Visualizamos las estadisticas principales

# %%
df.describe()
# Out:
#               Edad     Rotacion  Salario_Diario  Distancia_Hogar  \
# count  1470.000000  1470.000000     1470.000000      1470.000000
# mean     36.923810     0.161224      802.485714         9.192517
# std       9.135373     0.367863      403.509100         8.106864
# min      18.000000     0.000000      102.000000         1.000000
# 25%      30.000000     0.000000      465.000000         2.000000
# 50%      36.000000     0.000000      802.000000         7.000000
# 75%      43.000000     0.000000     1157.000000        14.000000
# max      60.000000     1.000000     1499.000000        29.000000
#
#        Nivel_Educativo  Conteo_Empleados  Numero_Empleado  \
# count      1470.000000            1470.0      1470.000000
# mean          2.912925               1.0      1024.865306
# std           1.024165               0.0       602.024335
# min           1.000000               1.0         1.000000
# 25%           2.000000               1.0       491.250000
# 50%           3.000000               1.0      1020.500000
# 75%           4.000000               1.0      1555.750000
# max           5.000000               1.0      2068.000000
#
#        Satisfaccion_Entorno  Salario_Hora  Compromiso_Trabajo  ...  \
# count           1470.000000   1470.000000         1470.000000  ...
# mean               2.721769     65.891156            2.729932  ...
# std                1.093082     20.329428            0.711561  ...
# min                1.000000     30.000000            1.000000  ...
# 25%                2.000000     48.000000            2.000000  ...
# 50%                3.000000     66.000000            3.000000  ...
# 75%                4.000000     83.750000            3.000000  ...
# max                4.000000    100.000000            4.000000  ...
#
#        Satisfaccion_Relaciones  Horas_Estandar  Nivel_Acciones  \
# count              1470.000000          1470.0     1470.000000
# mean                  2.712245            80.0        0.793878
# std                   1.081209             0.0        0.852077
# min                   1.000000            80.0        0.000000
# 25%                   2.000000            80.0        0.000000
# 50%                   3.000000            80.0        1.000000
# 75%                   4.000000            80.0        1.000000
# max                   4.000000            80.0        3.000000
#
#        Anios_Experiencia_Total  Capacitaciones_Ultimo_Anio  \
# count              1470.000000                 1470.000000
# mean                 11.279592                    2.799320
# std                   7.780782                    1.289271
# min                   0.000000                    0.000000
# 25%                   6.000000                    2.000000
# 50%                  10.000000                    3.000000
# 75%                  15.000000                    3.000000
# max                  40.000000                    6.000000
#
#        Balance_Vida_Trabajo  Anios_Empresa  Anios_Puesto_Actual  \
# count           1470.000000    1470.000000          1470.000000
# mean               2.761224       7.008163             4.229252
# std                0.706476       6.126525             3.623137
# min                1.000000       0.000000             0.000000
# 25%                2.000000       3.000000             2.000000
# 50%                3.000000       5.000000             3.000000
# 75%                3.000000       9.000000             7.000000
# max                4.000000      40.000000            18.000000
#
#        Anios_Desde_Promocion  Anios_Con_Jefe
# count            1470.000000     1470.000000
# mean                2.187755        4.123129
# std                 3.222430        3.568136
# min                 0.000000        0.000000
# 25%                 0.000000        2.000000
# 50%                 1.000000        3.000000
# 75%                 3.000000        7.000000
# max                15.000000       17.000000
#
# [8 rows x 27 columns]

# %%
print(df.groupby('Rotacion').size())
# Out:
# Rotacion
# 0    1233
# 1     237
# dtype: int64

# %%
# @title
import plotly.express as px

# Obtener el conteo de valores únicos en la columna 'comprar'
conteo_comprar = df['Rotacion'].value_counts()

# Crear un DataFrame con el conteo
df_conteo = pd.DataFrame({'Rotacion': conteo_comprar.index, 'cantidad': conteo_comprar.values})
df_conteo['Etiqueta'] = df_conteo['Rotacion'].apply(
    lambda x: 'Se Queda (0)' if x == 0 else 'Rota (1)'
)

# Crear el diagrama utilizando Plotly Express
fig = px.bar(
    df_conteo,
    x='Etiqueta', # Usamos la etiqueta para el eje X
    y='cantidad',
    title='Distribución del Desbalance de Clases',
    color='Etiqueta', # Asignar color por etiqueta
    color_discrete_map={'Se Queda (0)': '#00ff99', 'Rota (1)': '#ff00aa'} # Mapear los colores neón
)

# 🎨 Aplicar Estilo Neón y Oscuro
fig.update_layout(
    # Fondo y Tema
    template='plotly_dark',
    plot_bgcolor='rgba(0,0,0,0.6)',
    paper_bgcolor='#080014',

    # Título (Similar al h1/h2 del CSS)
    title={
        'font': {'color': '#00ffcc', 'size': 24, 'family': 'Orbitron, sans-serif'},
        'x': 0.5, # Centrar
        'xanchor': 'center'
    },

    # Ejes
    xaxis={
        'title': {'text': 'Clase de Rotación', 'font': {'color': '#00ff99'}},
        'tickfont': {'color': '#f5f5f5'},
        'gridcolor': '#1a1a1a'
    },
    yaxis={
        'title': {'text': 'Cantidad de Empleados', 'font': {'color': '#ff00aa'}},
        'tickfont': {'color': '#f5f5f5'},
        'gridcolor': '#1a1a1a'
    },

    # Leyenda
    legend={
        'title': {'text': 'Clase', 'font': {'color': '#ffb3e6'}},
        'font': {'color': '#f5f5f5'},
        'bgcolor': 'rgba(0,0,0,0.6)',
        'bordercolor': 'rgba(0, 255, 153, 0.44)', # Equivalente a #00ff99 con 44% de opacidad (70 en hex)
        'borderwidth': 1
    }
)

# Personalizar el estilo de las barras para que tengan un borde neón
fig.update_traces(
    marker_line_color='white', # Borde blanco alrededor de las barras
    marker_line_width=1.5,
    opacity=0.85
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7dc4aa45-76ac-4b45-b996-bf511c4b1052" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dc4aa45-76ac-4b45-b996-bf511c4b1052")) {                    Plotly.newPlot(                        "7dc4aa45-76ac-4b45-b996-bf511c4b1052",                        [{"alignmentgroup":"True","hovertemplate":"Etiqueta=%{x}\u003cbr\u003ecantidad=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Se Queda (0)","marker":{"color":"#00ff99","pattern":{"shape":""},"line":{"color":"white","width":1.5}},"name":"Se Queda (0)","offsetgroup":"Se Queda (0)","orientation":"v","showlegend":true,"textposition":"auto","x":["Se Queda (0)"],"xaxis":"x","y":[1233],"yaxis":"y","type":"bar","opacity":0.85},{"alignmentgroup":"True","hovertemplate":"Etiqueta=%{x}\u003cbr\u003ecantidad=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rota (1)","marker":{"color":"#ff00aa","pattern":{"shape":""},"line":{"color":"white","width":1.5}},"name":"Rota (1)","offsetgroup":"Rota (1)","orientation":"v","showlegend":true,"textposition":"auto","x":["Rota (1)"],"xaxis":"x","y":[237],"yaxis":"y","type":"bar","opacity":0.85}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b" ...

# %% [markdown]
# - Hicimos un gráfico de barras para ver la distribución de la rotación.”
# “Se observa que la mayoría de empleados se quedan en la empresa (0), mientras que una menor parte la abandona (1).
#
# - Esto muestra un desbalance en las clases, algo importante a tener en cuenta cuando entrenemos el modelo.
#
# - Ahora que entendemos cómo está distribuida la variable objetivo, pasamos a preparar el set de entrenamiento y prueba.

# %% [markdown]
# ###Simplificación de columnas para que el EDA sea más enfocado en la variable objetivo (Rotación) y, de paso, preparamos mejor los datos para el modelo.

# %% [markdown]
# ####Dropssss

# %%
import numpy as np

# 1) quitar columnas poco útiles
cols_drop = ["Numero_Empleado", "Conteo_Empleados", "Mayor_18", "Horas_Estandar"]
cols_drop = [c for c in cols_drop if c in df.columns]
df = df.drop(columns=cols_drop)

# %%
# 2) transformar ingreso mensual
if 'Ingreso_Mensual' in df.columns:
    df['log_Ingreso_Mensual'] = np.log1p(df['Ingreso_Mensual'])

# 3) agrupar Rol_Laboral
if 'Rol_Laboral' in df.columns:
    mapa_roles = {
        'Sales Executive':'Ventas', 'Sales Representative':'Ventas',
        'Research Scientist':'Investigacion', 'Laboratory Technician':'Investigacion',
        'Manufacturing Director':'Manufactura', 'Healthcare Representative':'Soporte',
        'Manager':'Direccion', 'Research Director':'Direccion',
        'Human Resources':'RRHH'
    }
    df['Rol_Laboral_agrupado'] = df['Rol_Laboral'].map(mapa_roles).fillna('Otros')

# 4) listas finales para gráficos
cols_num = [c for c in [
    'Edad', 'log_Ingreso_Mensual', 'Distancia_Hogar',
    'Anios_Experiencia_Total', 'Anios_Puesto_Actual', 'Anios_Empresa'
] if c in df.columns]

cols_cat = [c for c in [
    'Horas_Extra', 'Estado_Civil', 'Genero',
    'Rol_Laboral_agrupado', 'Balance_Vida_Trabajo', 'Satisfaccion_Trabajo'
] if c in df.columns]

# %% [markdown]
# - Eliminamos columnas poco útiles como número de empleado o mayor de 18.
#
# - Transformamos el ingreso mensual con logaritmo para que la distribución sea más clara.
#
# - Agrupamos los roles laborales en categorías más simples: ventas, investigación, dirección, soporte, etc.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Numéricas
n = len(cols_num)
rows = (n + 2) // 3
fig, axes = plt.subplots(rows, 3, figsize=(18, 5*rows))
axes = axes.flatten()

for i, col in enumerate(cols_num):
    axes[i].hist(df[col].dropna(), bins=20, color='magenta', edgecolor='cyan')
    axes[i].set_title(f'Distribución de {col.replace("_", " ").lower()}'.capitalize())

for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.suptitle("Distribución de variables numéricas seleccionadas", fontsize=16, weight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# Categóricas
m = len(cols_cat)
rows = (m + 2) // 3
fig, axes = plt.subplots(rows, 3, figsize=(18, 5*rows))
axes = axes.flatten()

for i, col in enumerate(cols_cat):
    order = sorted(df[col].dropna().unique(), key=lambda x: x) if df[col].dtype == 'O' else None
    sns.countplot(x=df[col], ax=axes[i], palette="viridis", order=order)
    axes[i].set_title(f'Distribución de {col.replace("_", " ").lower()}'.capitalize())
    axes[i].tick_params(axis='x', rotation=35)

for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.suptitle("Distribución de variables categóricas seleccionadas", fontsize=16, weight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# /tmp/ipython-input-1257084241.py:29: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /tmp/ipython-input-1257084241.py:29: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /tmp/ipython-input-1257084241.py:29: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /tmp/ipython-input-1257084241.py:29: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /tmp/ipython-input-1257084241.py:29: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /tmp/ipython-input-1257084241.py:29: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ##Resultados de los gráficos
#
# **Variables numéricas:**
#
# - La edad se concentra entre 30 y 40 años.
#
# - Los ingresos muestran mucha variabilidad, con mayor concentración en rangos medios.
#
# - La mayoría vive cerca de la empresa (distancia baja).
# Los años de experiencia y permanencia tienden a ser pocos: muchos empleados con menos de 10 años.
#
# **Variables categóricas:**
#
# - Más empleados trabajan sin horas extra que con ellas.
#
# - Estado civil: predominan los casados, seguidos de solteros y divorciados.
# Género: ligera mayoría de hombres.
#
# - Rol laboral: destacan investigación y ventas.
#
# - Balance vida-trabajo: la mayoría lo evalúa como “3” (medio).
#
# - Satisfacción en el trabajo: se concentra en valores medios-altos (3 y 4).

# %% [markdown]
# ###Creamos variables compuestas “útiles para el modelo”, eliminamos columnas redundantes y creamos un **df_modelo**

# %%
import numpy as np
import pandas as pd

df = df.copy()

# Compensación en escala log (más estable ante asimetrías)
if 'Ingreso_Mensual' in df.columns:
    df['log_Ingreso_Mensual'] = np.log1p(df['Ingreso_Mensual'])

# Satisfacción compuesta: promedio simple de escalas disponibles
cols_satis = [c for c in df.columns if c.lower().startswith('satisfaccion')]
if cols_satis:
    df['Satisfaccion_Global'] = df[cols_satis].mean(axis=1)

# Balance de vida-trabajo normalizado a 0–1 (si escala 1–4)
if 'Balance_Vida_Trabajo' in df.columns:
    max_bal = df['Balance_Vida_Trabajo'].max()
    df['Balance_Normalizado'] = (df['Balance_Vida_Trabajo'] - 1) / (max_bal - 1) if max_bal > 1 else df['Balance_Vida_Trabajo']

# Distancia capada para outliers extremos (winsor 99%)
if 'Distancia_Hogar' in df.columns:
    p99 = df['Distancia_Hogar'].quantile(0.99)
    df['Distancia_capped'] = np.minimum(df['Distancia_Hogar'], p99)

# %% [markdown]
# - Generamos nuevas variables compuestas enriquecen el dataset y ayudan al modelo a detectar patrones más claros sobre la rotación de empleados.

# %% [markdown]
# ####Dropssss

# %%
# Definir columnas a descartar (IDs, constantes o redundantes)
cols_drop = [c for c in [
    'Ingreso_Mensual','Distancia_Hogar','Rol_Laboral',
    'Satisfaccion_Entorno','Satisfaccion_Trabajo','Satisfaccion_Relaciones'  # reemplazadas por derivadas
] if c in df.columns]

df_limpio = df.drop(columns=cols_drop)

# %%
target = 'Rotacion'

cols_num = [c for c in [
    'Edad','Anios','Anios_Empresa','Anios_Puesto_Actual',
    'log_Ingreso_Mensual','Distancia_capped','Satisfaccion_Global','Balance_Normalizado'
] if c in df_limpio.columns]

cols_cat = [c for c in [
    'Estado_Civil','Genero','Rol_Laboral_agrupado','Horas_Extra',
    'Balance_Vida_Trabajo','Satisfaccion_Trabajo'
] if c in df_limpio.columns]

cols_modelo = [c for c in (cols_num + cols_cat + [target]) if c in df_limpio.columns]
df_modelo = df_limpio[cols_modelo].copy()

# %%
# Resumen numérico
print(df_modelo.select_dtypes(include=np.number).describe().T)

# Conteo de la variable objetivo (balance de clases)
if target in df_modelo.columns:
    print("\nDistribución de la variable objetivo:")
    print(df_modelo[target].value_counts(normalize=True).rename('proporcion').to_frame())
# Out:
#                        count       mean       std        min        25%  \
# Edad                  1470.0  36.923810  9.135373  18.000000  30.000000
# Anios_Empresa         1470.0   7.008163  6.126525   0.000000   3.000000
# Anios_Puesto_Actual   1470.0   4.229252  3.623137   0.000000   2.000000
# log_Ingreso_Mensual   1470.0   8.552752  0.664313   6.917706   7.976595
# Distancia_capped      1470.0   9.192517  8.106864   1.000000   2.000000
# Satisfaccion_Global   1470.0   2.720862  0.628240   1.000000   2.333333
# Balance_Normalizado   1470.0   0.587075  0.235492   0.000000   0.333333
# Balance_Vida_Trabajo  1470.0   2.761224  0.706476   1.000000   2.000000
# Rotacion              1470.0   0.161224  0.367863   0.000000   0.000000
#
#                             50%        75%        max
# Edad                  36.000000  43.000000  60.000000
# Anios_Empresa          5.000000   9.000000  40.000000
# Anios_Puesto_Actual    3.000000   7.000000  18.000000
# log_Ingreso_Mensual    8.501061   9.033603   9.903488
# Distancia_capped       7.000000  14.000000  29.000000
# Satisfaccion_Global    2.666667   3.333333   4.000000
# Balance_Normalizado    0.666667   0.666667   1.000000
# Balance_Vida_Trabajo   3.000000   3.000000   4.000000
# Rotacion               0.000000   0.000000   1.000000
#
# Distribución de la variable objetivo:
#           proporcion
# Rotacion
# 0           0.838776
# 1           0.161224

# %%
df_modelo.describe()
# Out:
#               Edad  Anios_Empresa  Anios_Puesto_Actual  log_Ingreso_Mensual  \
# count  1470.000000    1470.000000          1470.000000          1470.000000
# mean     36.923810       7.008163             4.229252             8.552752
# std       9.135373       6.126525             3.623137             0.664313
# min      18.000000       0.000000             0.000000             6.917706
# 25%      30.000000       3.000000             2.000000             7.976595
# 50%      36.000000       5.000000             3.000000             8.501061
# 75%      43.000000       9.000000             7.000000             9.033603
# max      60.000000      40.000000            18.000000             9.903488
#
#        Distancia_capped  Satisfaccion_Global  Balance_Normalizado  \
# count       1470.000000          1470.000000          1470.000000
# mean           9.192517             2.720862             0.587075
# std            8.106864             0.628240             0.235492
# min            1.000000             1.000000             0.000000
# 25%            2.000000             2.333333             0.333333
# 50%            7.000000             2.666667             0.666667
# 75%           14.000000             3.333333             0.666667
# max           29.000000             4.000000             1.000000
#
#        Balance_Vida_Trabajo     Rotacion
# count           1470.000000  1470.000000
# mean               2.761224     0.161224
# std                0.706476     0.367863
# min                1.000000     0.000000
# 25%                2.000000     0.000000
# 50%                3.000000     0.000000
# 75%                3.000000     0.000000
# max                4.000000     1.000000

# %% [markdown]
# - Eliminamos columnas redundantes, como las originales de ingreso o satisfacción, porque ya teníamos sus versiones derivadas.
#
# - Definimos las variables numéricas y categóricas que van a entrar en el modelo, junto con la variable objetivo: Rotación.
#
# - Creamos un dataset limpio (df_modelo) con solo las variables útiles para entrenar.
#
#
# **Resumen estadístico**
#
# - La edad promedio es de 37 años, la mayoría con menos de 10 años en la empresa y menos de 5 en su puesto actual.
#
# - El balance vida-trabajo y la satisfacción global se concentran en valores intermedios.
#
# - La variable objetivo confirma el desbalance: 84% se queda, 16% se va.
#
# 👉 Conclusión:
#  - Ya tenemos un dataset compacto, limpio y con variables relevantes, listo para entrenar los modelos predictivos.

# %% [markdown]
# #Implementación del algoritmo Bayes

# %% [markdown]
# Selección de variables con **SelectKBest**: Preprocesamos (imputa y codifica dummies), calculamos relevancia univariante contra Rotacion con mutual_info_classif y devolvemos las k mejores features (incluye dummies de categóricas).

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, mutual_info_classif
import numpy as np

# Definiciones

target = 'Rotacion'
X = df_modelo.drop(columns=[target]).copy()
y = df_modelo[target].astype('category').cat.codes  # codificamos target

# Separar variables numéricas y categóricas
num_vars = X.select_dtypes(include=np.number).columns.tolist()
cat_vars = X.select_dtypes(exclude=np.number).columns.tolist()


# Preprocesamiento
# Pipeline numérico
num_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='median'))
])

# Pipeline categórico con OneHotEncoder
cat_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

# ColumnTransformer que une todo
pre = ColumnTransformer([
    ('num', num_pipe, num_vars),
    ('cat', cat_pipe, cat_vars)
])

# Selección de features

k = 12  # número de features a conservar

sel_pipe = Pipeline([
    ('pre', pre),
    ('sel', SelectKBest(score_func=mutual_info_classif, k=k))
])

# Fit y transformación
X_sel = sel_pipe.fit_transform(X, y)

# Recuperar nombres de features seleccionadas
# Nombres de numéricas
num_names = np.array(num_vars)

# Nombres de categóricas (OneHotEncoder)
ohe = sel_pipe.named_steps['pre'].named_transformers_['cat'].named_steps['ohe'] if len(cat_vars) > 0 else None
cat_names = ohe.get_feature_names_out(cat_vars) if ohe is not None else np.array([])

# Concatenamos nombres
feature_names = np.r_[num_names, cat_names]

# Máscara de seleccionadas
mask = sel_pipe.named_steps['sel'].get_support()
features_top = feature_names[mask]

print(f"Top {k} variables seleccionadas:\n", features_top)
# Out:
# Top 12 variables seleccionadas:
#  ['Edad' 'Anios_Empresa' 'Anios_Puesto_Actual' 'log_Ingreso_Mensual'
#  'Balance_Vida_Trabajo' 'Estado_Civil_Divorced' 'Estado_Civil_Married'
#  'Estado_Civil_Single' 'Genero_Male' 'Rol_Laboral_agrupado_Investigacion'
#  'Horas_Extra_No' 'Horas_Extra_Yes']

# %% [markdown]
# - Aplicamos un proceso de preprocesamiento: imputaión de valores faltantes, codificación de variables categóricas y escalado.
#
# - Usamos SelectKBest con información mutua para quedarnos con las 12 variables más importantes.
#
# - Entre ellas aparecen: Edad, Años en la empresa, Años en el puesto, Ingreso logarítmico, Satisfacción global, Balance vida-trabajo y Horas Extra.”
# “También influyen características personales como el estado civil y el rol laboral.
#
# - Con estas 12 variables clave ya tenemos un dataset optimizado y listo para entrenar modelos de predicción de rotación.

# %% [markdown]
# Mapa de calor de correlación de Pearson

# %%
# Correlación entre numéricas del df_modelo
numericas_disponibles = df_modelo.select_dtypes(include=np.number).drop(columns=[target], errors='ignore')
plt.figure(figsize=(10,8))
sns.heatmap(numericas_disponibles.corr(), annot=True, fmt=".2f",
            cmap=plt.cm.Spectral, linewidths=0.1, linecolor='white', square=True)
plt.title("Correlación de Pearson entre variables numéricas")
plt.tight_layout()
plt.show()

# %% [markdown]
# - Calculamos la correlación de Pearson entre variables numéricas para detectar relaciones fuertes.
#
# - Vemos que los años en la empresa y los años en el puesto actual están muy correlacionados.
#
# - También hay correlación moderada entre ingreso y antigüedad (0.49–0.51).
#
# - Las demás variables muestran baja correlación, lo que significa que cada una aporta información distinta al modelo.

# %%
# Histogramas de numéricas más relevantes
usadas_num = [c for c in ['Edad','Anios_Empresa','Anios_Puesto_Actual',
                          'log_Ingreso_Mensual','Distancia_capped',
                          'Ratio_Antiguedad_Puesto']
              if c in numericas_disponibles.columns]

df_modelo[usadas_num].hist(color='blue', edgecolor='cyan', figsize=(12,8), bins=20)
plt.show()

# %% [markdown]
# - Estos histogramas nos muestran que la mayoría de empleados son jóvenes, llevan pocos años en la empresa y suelen vivir cerca, lo cual influye en los patrones de rotación.
#
# - Edad: se concentra entre 30 y 40 años.
#
# - Años en la empresa y años en el puesto actual: la mayoría tiene poca antigüedad (menos de 10 años).
#
# - Ingreso mensual logarítmico: distribuido en rangos medios, sin valores extremos tan marcados.
#
# - Distancia al hogar: la mayoría vive muy cerca de la empresa.
#
# - Ratio antigüedad-puesto: muchos empleados están relativamente poco tiempo en el puesto en comparación con su permanencia total.

# %% [markdown]
# Split y Pipeline de Naive Bayes

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, RocCurveDisplay
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.model_selection import train_test_split

# Semilla
np.random.seed(42)

# Train/Test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# Pipeline completo (pre + select k + denso + NB)
to_dense = FunctionTransformer(lambda A: A.toarray() if hasattr(A,"toarray") else A)

#---------------------------
#BALANCEO CON SMOTE PARA NB!!
#---------------------------
nb_smote= ImbPipeline([
    ('pre', pre),
    ('smote', SMOTE(random_state=42)), # PASO DE BALANCEO
    ('sel', SelectKBest(
        score_func=lambda X, y: mutual_info_classif(X, y, random_state=42),
        k=k
    )),
    ('to_dense', to_dense),
    ('clf', GaussianNB())
])

nb_smote.fit(X_train, y_train) # SE ENTRENA CON EL NUEVO PIPELINE

y_pred = nb_smote.predict(X_test)
y_prob = nb_smote.predict_proba(X_test)[:,1]

# Evaluación
print("Evaluando Naive Bayes SMOTE...")
res_nb = evalua_modelo(nb_smote, 'Naive Bayes SMOTE')
print(f"NB SMOTE F1(1): {res_nb['f11']:.3f}")

print("Reporte de clasificación:\n", classification_report(y_test, y_pred, digits=3))
print("ROC AUC:", roc_auc_score(y_test, y_prob))
# Evaluación
# Out:
# Evaluando Naive Bayes SMOTE...
# NB SMOTE F1(1): 0.507
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0      0.931     0.738     0.823       309
#            1      0.341     0.712     0.462        59
#
#     accuracy                          0.734       368
#    macro avg      0.636     0.725     0.642       368
# weighted avg      0.836     0.734     0.765       368
#
# ROC AUC: 0.7736273380505732

# %%
# Matriz de confusión (versión seaborn)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4,3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de confusión - Naive Bayes')
plt.xlabel('Predicción'); plt.ylabel('Real')
plt.tight_layout(); plt.show()

# %% [markdown]
# - Dividimos los datos en train (75%) y test (25%), aplicando un pipeline completo con preprocesamiento, selección de variables y Naive Bayes.
#
# - El modelo alcanzó una accuracy de 79,6% y un ROC AUC de 0.75, lo que indica un buen poder de discriminación.
#
# **Métricas principales:**
#
# Clase 0 (se queda): alta precisión (0.93) y buen recall (0.81).
#
# Clase 1 (se va): precisión baja (0.41) pero recall aceptable (0.69), lo que significa que el modelo logra detectar a una parte importante de quienes se van, aunque con falsos positivos.
#
# F1-score de la clase 1: 0.51, muestra espacio de mejora.
#
#
# **Matriz de confusión:**
#
# 252 Personas que realmente se quedaron en la empresa y el modelo predijo
#
# 57 Personas que realmente se quedaron en la empresa, pero el modelo predijo “abandona” (falsos positivos).correctamente “se queda”.
#
# 18 Personas que realmente abandonaron la empresa, pero el modelo predijo “se queda” (falsos negativos).
#
# 41 Personas que realmente abandonaron la empresa y el modelo predijo correctamente “abandona”.
#
#
# 👉 Conclusión del modelo:
# El Naive Bayes es capaz de capturar un patrón claro en la rotación, con buena capacidad para identificar a empleados que se quedan, aunque aún con margen de mejora en la predicción de quienes abandonan la empresa.

# %% [markdown]
# # ¿Mejora del modelo subiendo el recall y bajando el umbral?

# %%
from sklearn.metrics import precision_recall_curve, classification_report, confusion_matrix
import numpy as np

probs = nb_smote.predict_proba(X_test)[:,1]
p, r, th = precision_recall_curve(y_test, probs)

# umbral que maximiza F2 (prioriza recall)
f2 = (1+2**2)*(p*r)/((2**2)*p + r + 1e-9)
thr = th[np.nanargmax(f2)]
y_pred_thr = (probs >= thr).astype(int)

print("Umbral F2:", round(float(thr),4))
print(classification_report(y_test, y_pred_thr, digits=3))
print(confusion_matrix(y_test, y_pred_thr))
# Out:
# Umbral F2: 0.4757
#               precision    recall  f1-score   support
#
#            0      0.946     0.731     0.825       309
#            1      0.357     0.780     0.489        59
#
#     accuracy                          0.739       368
#    macro avg      0.651     0.756     0.657       368
# weighted avg      0.851     0.739     0.771       368
#
# [[226  83]
#  [ 13  46]]

# %%
import plotly.graph_objects as go
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_thr, labels=[0,1])

fig = go.Figure(data=go.Heatmap(
    z=cm,
    x=['Predijo: No rotación','Predijo: Rotación'],
    y=['Real: No rotación','Real: Rotación'],
    colorscale='Blues',
    text=cm,
    texttemplate="%{text}",
    showscale=True
))
fig.update_layout(
    title='Matriz de confusión - Naive Bayes (umbral F2)',
    xaxis_title='Predicción',
    yaxis_title='Real',
    autosize=False, width=650, height=420
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b5405df1-06e3-42c2-be81-707b7436fb8a" class="plotly-graph-div" style="height:420px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5405df1-06e3-42c2-be81-707b7436fb8a")) {                    Plotly.newPlot(                        "b5405df1-06e3-42c2-be81-707b7436fb8a",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"showscale":true,"text":[[226,83],[13,46]],"texttemplate":"%{text}","x":["Predijo: No rotación","Predijo: Rotación"],"y":["Real: No rotación","Real: Rotación"],"z":[[226,83],[13,46]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo ...

# %% [markdown]
# Si, según el objetivo que planteamos...
#
# Al ser nuestro objetivo no perder renuncias (maximizar recall de la clase 1): mejora. Subimos el recall de 0.69 → 0.76 (detectamos más gente que se va).
#
# Pero también baja la precisión (0.418 → 0.402) y la accuracy (0.79 → 0.78). La precisión/accuracy no mejora; el modelo dispara más falsos positivos.
#
# Pero viendo los numeros, el accuracy y presicion no tiene un cambio muy drastico entonces esto parece estar mejor con el cambio.
#
# **En conclusion**
#
# Si mejora en terminos de recall, ahora perdemos menos abandonos de empleados **14 vs 18**
#
# El costo seria que la empresa se preocupará por más falsos positivos **67 empleados que no se iban a ir, pero el modelo creyo que habia riesgo de abandono**
#
# En el contexto dde RRHH, esto puede ser lo mas aceptable, **mejor invertir en retener a empleados que no se iban a ir, que perder talento para la empresa por no haberlo detectado**

# %% [markdown]
# ## **BALANCEO Y OPTIMIZACIÓN DE MODELOS FALTANTES (SMOTE)**
# Para asegurar que todos los modelos base del Stacking Classifier (RL, RF, NB) usen SMOTE antes de que el Stacking los combine.

# %% [markdown]
# Funciones de evaluacion modelo RF y RL
#
# - def umbral_f1:
# Cuando un modelo calcula una probabilidad de rotación (ej. $0.35$), necesita una regla de decisión para convertir esa probabilidad en una predicción binaria ($0$ o $1$). Estos usan un **umbral estandar (0.5)**. Esta funcion encuentra el punto de corte optimo que maximiza el rendimiento del modelo, especifica para la clase minoritaria (rotacion).

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Umbral F1
def umbral_f1(probs, y_true):
    p, r, th = precision_recall_curve(y_true, probs)
    if th.size == 0:
        return 0.5
    f1 = 2 * p[1:] * r[1:] / (p[1:] + r[1:] + 1e-9)
    return th[np.nanargmax(f1)]

# Función de Evaluación
def evalua_modelo(pipe, nombre):
    pipe.fit(X_train, y_train)
    probs = pipe.predict_proba(X_test)[:,1]
    thr = umbral_f1(probs, y_test)
    y_pred = (probs >= thr).astype(int)

    # métricas
    auc = roc_auc_score(y_test, probs)
    acc = accuracy_score(y_test, y_pred)
    # precision/recall/F1 de la clase 1 desde el reporte
    rep = classification_report(y_test, y_pred, output_dict=True)
    prec1 = rep['1']['precision']; rec1 = rep['1']['recall']; f11 = rep['1']['f1-score']

    # curva ROC
    fpr, tpr, _ = roc_curve(y_test, probs)

    return {
        'nombre': nombre, 'pipe': pipe, 'probs': probs, 'thr': thr,
        'auc': auc, 'acc': acc, 'prec1': prec1, 'rec1': rec1, 'f11': f11,
        'fpr': fpr, 'tpr': tpr
    }

# Helper para Naive Bayes
to_dense = FunctionTransformer(lambda A: A.toarray() if hasattr(A, "toarray") else A)

# %%
# ----------------------------------------------------------------------
# 2. Definición y Optimización de Regresión Logística con SMOTE
# ----------------------------------------------------------------------

# Pipeline de Regresión Logística con SMOTE
smote_logit = ImbPipeline([
    ('pre', pre),
    ('smote', SMOTE(random_state=42)),
    ('clf', LogisticRegression(max_iter=1000, solver='lbfgs', random_state=42))
])

# GridSearch para Logística
print("Iniciando GridSearch de Regresión Logística (SMOTE)...")
grid_logit = {'clf__C': [0.1, 0.5, 1, 2]}
gs_log = GridSearchCV(smote_logit, grid_logit, scoring='f1', cv=cv, n_jobs=-1)
gs_log.fit(X_train, y_train)
best_log = gs_log.best_estimator_
print(f"Mejor C para Logística (SMOTE): {gs_log.best_params_['clf__C']}")

# Evaluación
res_log = evalua_modelo(best_log, 'Regresión Logística SMOTE')
print(f"RL SMOTE F1(1): {res_log['f11']:.3f}")
# Out:
# Iniciando GridSearch de Regresión Logística (SMOTE)...
# Mejor C para Logística (SMOTE): 0.1
# RL SMOTE F1(1): 0.562

# %%
# ----------------------------------------------------------------------
# 3. Definición y Optimización de Random Forest con SMOTE
# ----------------------------------------------------------------------

# Pipeline de Random Forest con SMOTE
smote_rf = ImbPipeline([
    ('pre', pre),
    ('smote', SMOTE(random_state=42)),
    ('clf', RandomForestClassifier(random_state=42, n_jobs=-1))
])

# GridSearch para Random Forest
print("\nIniciando GridSearch de Random Forest (SMOTE)...")
grid_rf = {
    'clf__n_estimators': [300, 500],
    'clf__max_depth': [10, None],
    'clf__min_samples_leaf': [1, 2, 4],
}
gs_rf = GridSearchCV(smote_rf, grid_rf, scoring='f1', cv=cv, n_jobs=-1)
gs_rf.fit(X_train, y_train)
best_rf = gs_rf.best_estimator_
print(f"Mejores parámetros para RF (SMOTE): {gs_rf.best_params_}")

# Evaluación
res_rf = evalua_modelo(best_rf, 'Random Forest SMOTE')
print(f"RF SMOTE F1(1): {res_rf['f11']:.3f}")
# Out:
# Iniciando GridSearch de Random Forest (SMOTE)...
# Mejores parámetros para RF (SMOTE): {'clf__max_depth': 10, 'clf__min_samples_leaf': 1, 'clf__n_estimators': 300}
# RF SMOTE F1(1): 0.513

# %% [markdown]
# **Como nos sugirio el profe implemente ''SMOTE'', una técnica de sobremuestreo sintetico de la clase minoritaria. Smote es un algoritmo de sobremuestreo muy util para abordar problemas de desbalance de clases. Esto lo resuelve creando nuevas instancias sinteticas para la clase minoritaria.**
#
# FUNCIONAMIENTO:
# - Para cada instancia $x_i$ de la clase minoritaria, SMOTE encuentra sus $k$ vecinos más cercanos (utilizando, por ejemplo, la distancia Euclidiana) dentro de la misma clase minoritaria.
# - Selecciona aleatoriamente uno de estos $k$ vecinos más cercanos ($x_{zn}$).
# - Genera un nuevo ejemplo sintético.
#
# **Este proceso ayuda a que el conjunto de datos se vuelva más balanceado, lo que permite que el modelo aprenda mejor las características de la clase minoritaria y mejore su rendimiento general.**
#
# SMOTE se implementa dentro de ImbPipeline, una version especializada de Pipeline. Si intentaramos usar el Pipeline estándar de scikit-learn para integrar SMOTE, podríamos encontrarnos con un Data Leakage, porque aplicariamos SMOTE a todo el conjunto de datos de entrenamiento antes de la validación cruzada, los ejemplos sintéticos creados se basarían en información tanto del fold de entrenamiento como del fold de validación. Esto sobreestima el rendimiento real del modelo porque el clasificador ya ha "visto" información de los datos de validación a través de los ejemplos sintéticos.

# %% [markdown]
# #**Stacking Classifier**

# %%
# @title
# ----------------------------------------------------------------------
# 4. Implementación del Stacking Classifier
# ----------------------------------------------------------------------
print("\n--- STACKING CLASSIFIER (Modelos Base: SMOTE) ---")

# Definición de Estimadores Base (los tres modelos optimizados con SMOTE)
estimators_smote = [
    ('log', best_log),
    ('rf', best_rf),
    ('nb', nb_smote)
]

# Creación y Evaluación del Stacking Classifier
stacking_pipe_smote = StackingClassifier(
    estimators=estimators_smote,
    final_estimator=LogisticRegression(solver='lbfgs', max_iter=1000, random_state=42),
    cv=cv,
    n_jobs=-1
)

print("Evaluando Stacking Classifier...")
res_stacking_smote = evalua_modelo(stacking_pipe_smote, 'Stacking (SMOTE)')


# ----------------------------------------------------------------------
# 5. Resumen FINAL
# ----------------------------------------------------------------------

# Recopilamos todos los resultados
todos_los_resultados_smote = [res_nb, res_log, res_rf, res_stacking_smote]

resumen_final_smote = pd.DataFrame([
    {'Modelo': r['nombre'], 'AUC': r['auc'], 'Precisión(1)': r['prec1'],
     'Recall(1)': r['rec1'], 'F1(1)': r['f11'], 'Accuracy': r['acc'], 'Umbral F1': r['thr']}
    for r in todos_los_resultados_smote
]).sort_values('AUC', ascending=False)


print("\n### 👑 Resumen FINAL de Métricas (SMOTE + Stacking) ###")
print(resumen_final_smote.round(3))
# Out:
# --- STACKING CLASSIFIER (Modelos Base: SMOTE) ---
# Evaluando Stacking Classifier...
#
# ### 👑 Resumen FINAL de Métricas (SMOTE + Stacking) ###
#                       Modelo    AUC  Precisión(1)  Recall(1)  F1(1)  Accuracy  \
# 1  Regresión Logística SMOTE  0.805         0.522      0.610  0.562     0.848
# 3           Stacking (SMOTE)  0.803         0.547      0.593  0.569     0.856
# 2        Random Forest SMOTE  0.784         0.517      0.508  0.513     0.845
# 0          Naive Bayes SMOTE  0.774         0.443      0.593  0.507     0.815
#
#    Umbral F1
# 1      0.640
# 3      0.278
# 2      0.359
# 0      0.716

# %%
# @title

# --- ESTILOS DE TABLA NEÓN ---
HTML_STYLE = '''
<style>
@import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');

.neon-table {
    border-collapse: separate;
    border-spacing: 0;
    width: 100%;
    margin: 20px 0;
    font-family: 'Poppins', sans-serif;
    color: #f5f5f5;
    box-shadow: 0 0 20px rgba(0, 255, 153, 0.5), 0 0 10px rgba(255, 0, 170, 0.5);
    border-radius: 10px;
    overflow: hidden; /* Para que el border-radius funcione */
}

.neon-table th, .neon-table td {
    padding: 12px 15px;
    text-align: center;
    border-bottom: 1px solid rgba(0, 255, 153, 0.3);
}

.neon-table th {
    background-color: rgba(255, 0, 170, 0.2); /* Fondo rosa oscuro */
    color: #00ff99; /* Texto cian neón */
    text-transform: uppercase;
    font-size: 0.9em;
    font-weight: 700;
    letter-spacing: 1px;
    border-top: 2px solid #00ff99;
}

.neon-table tr:nth-child(even) {
    background-color: rgba(0, 0, 0, 0.4);
}

.neon-table tr:nth-child(odd) {
    background-color: rgba(10, 0, 15, 0.5);
}

.neon-table tr:hover {
    background-color: rgba(255, 0, 170, 0.1);
}

.neon-table .auc-column {
    color: #ffb3e6; /* Rosa brillante para la métrica clave */
    font-weight: bold;
    text-shadow: 0 0 5px #ff00aa;
}

.neon-header {
    text-align: center;
    font-size: 2.0em;
    color: #00ffcc;
    text-shadow: 0 0 15px #00ff99aa;
    font-family: 'Orbitron', sans-serif;
    margin-top: 30px;
    margin-bottom: 15px;
}
</style>
'''

def display_neon_dataframe(df, title):
    """Muestra un DataFrame con el estilo neón."""
    html_output = HTML_STYLE
    html_output += f'<div class="neon-header">👑 {title} 👑</div>'

    # Aplicar clase CSS a las celdas de la columna AUC
    styled_df = df.style.set_table_attributes('class="neon-table"')

    # Enfatizar la columna AUC
    styled_df = styled_df.apply(
        lambda x: ['background-color: rgba(0, 255, 153, 0.15)' if x.name == 'AUC' else '' for i in x], axis=1
    )

    # Renderizar el DataFrame a HTML
    html_output += styled_df.to_html(classes='neon-table', index=False, float_format="%.3f")
    display(HTML(html_output))


# ----------------------------------------------------------------------
# 4. Implementación del Stacking Classifier (Parte Funcional)
# ----------------------------------------------------------------------
print("\n--- STACKING CLASSIFIER (Modelos Base: SMOTE) ---")

# NOTA: Esta sección requiere que las variables de tu entorno (best_log, best_rf, etc.) estén definidas.
try:
    # Definición de Estimadores Base (los tres modelos optimizados con SMOTE)
    estimators_smote = [
        ('log', best_log),
        ('rf', best_rf),
        ('nb', nb_smote)
    ]

    # Creación y Evaluación del Stacking Classifier
    stacking_pipe_smote = StackingClassifier(
        estimators=estimators_smote,
        final_estimator=LogisticRegression(solver='lbfgs', max_iter=1000, random_state=42),
        cv=cv,
        n_jobs=-1
    )

    print("Evaluando Stacking Classifier...")
    res_stacking_smote = evalua_modelo(stacking_pipe_smote, 'Stacking (SMOTE)')

    # ----------------------------------------------------------------------
    # 5. Resumen FINAL (Parte de Visualización)
    # ----------------------------------------------------------------------

    # Recopilamos todos los resultados
    todos_los_resultados_smote = [res_nb, res_log, res_rf, res_stacking_smote]

    resumen_final_smote = pd.DataFrame([
        {'Modelo': r['nombre'], 'AUC': r['auc'], 'Precisión(1)': r['prec1'],
         'Recall(1)': r['rec1'], 'F1(1)': r['f11'], 'Accuracy': r['acc'], 'Umbral F1': r['thr']}
        for r in todos_los_resultados_smote
    ]).sort_values('AUC', ascending=False).round(3)


    # Reemplazo del print() por la función de visualización HTML
    display_neon_dataframe(resumen_final_smote, "Resumen FINAL de Métricas (SMOTE + Stacking)")

except NameError as e:
    # Este bloque solo se ejecuta si faltan las variables de entorno necesarias (como 'best_log')
    print("\n--- ERROR DE EJECUCIÓN ---")
    print(f"El código funcional no pudo ejecutarse porque faltan variables clave como 'best_log', 'evalua_modelo', o 'cv'.")
    print("El código HTML para el DataFrame se ha definido correctamente, pero necesitas ejecutar las celdas anteriores.")

    # Mostrar un DataFrame de ejemplo con el estilo HTML
    ejemplo_data = {
        'Modelo': ['Regresión Logística SMOTE', 'Stacking (SMOTE)', 'Random Forest SMOTE', 'Naive Bayes SMOTE'],
        'AUC': [0.805, 0.803, 0.784, 0.774],
        'Precisión(1)': [0.522, 0.547, 0.517, 0.443],
        'Recall(1)': [0.610, 0.593, 0.508, 0.593],
        'F1(1)': [0.562, 0.569, 0.513, 0.507],
        'Accuracy': [0.848, 0.856, 0.845, 0.815],
        'Umbral F1': [0.640, 0.278, 0.359, 0.716]
    }
    ejemplo_df = pd.DataFrame(ejemplo_data).sort_values('AUC', ascending=False).round(3)
    display_neon_dataframe(ejemplo_df, "EJEMPLO: Resumen FINAL de Métricas (SMOTE + Stacking)")
# Out:
# --- STACKING CLASSIFIER (Modelos Base: SMOTE) ---
# Evaluando Stacking Classifier...
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');
#
# .neon-table {
#     border-collapse: separate;
#     border-spacing: 0;
#     width: 100%;
#     margin: 20px 0;
#     font-family: 'Poppins', sans-serif;
#     color: #f5f5f5;
#     box-shadow: 0 0 20px rgba(0, 255, 153, 0.5), 0 0 10px rgba(255, 0, 170, 0.5);
#     border-radius: 10px;
#     overflow: hidden; /* Para que el border-radius funcione */
# }
#
# .neon-table th, .neon-table td {
#     padding: 12px 15px;
#     text-align: center;
#     border-bottom: 1px solid rgba(0, 255, 153, 0.3);
# }
#
# .neon-table th {
#     background-color: rgba(255, 0, 170, 0.2); /* Fondo rosa oscuro */
#     color: #00ff99; /* Texto cian neón */
#     text-transform: uppercase;
#     font-size: 0.9em;
#     font-weight: 700;
#     letter-spacing: 1px;
#     border-top: 2px solid #00ff99;
# }
#
# .neon-table tr:nth-child(even) {
#     background-color: rgba(0, 0, 0, 0.4);
# }
#
# .neon-table tr:nth-child(odd) {
#     background-color: rgba(10, 0, 15, 0.5);
# }
#
# .neon-table tr:hover {
#     background-color: rgba(255, 0, 170, 0.1);
# }
#
# .neon-table .auc-column {
#     color: #ffb3e6; /* Rosa brillante para la métrica clave */
#     font-weight: bold;
#     text-shadow: 0 0 5px #ff00aa;
# }
#
# .neon-header {
#     text-align: center;
#     font-size: 2.0em;
#     color: #00ffcc;
#     text-shadow: 0 0 15px #00ff99aa;
#     font-family: 'Orbitron', sans-serif;
#     margin-top: 30px;
#     margin-bottom: 15px;
# }
# </style>
# <div class="neon-header">👑 Resumen FINAL de Métricas (SMOTE + Stacking) 👑</div><style type="text/css">
# </style>
# <table id="T_2e3bc" class="neon-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e3bc_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_2e3bc_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2e3bc_level0_col2" class="col_heading level0 col2" >Precisión(1)</th>
#       <th id="T_2e3bc_level0_col3" class="col_heading level0 col3" >Recall(1)</th>
#       <th id="T_2e3bc_level0_col4" class="col_heading level0 col4" >F1(1)</th>
#       <th id="T_2e3bc_level0_col5" class="col_heading level0 col5" >Accuracy</th>
#       <th id="T_2e3bc_level0_col6" class="col_heading level0 col6" >Umbral F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e3bc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2e3bc_row0_col0" class="data row0 col0" >Regresión Logística SMOTE</td>
#       <td id="T_2e3bc_row0_col1" class="data row0 col1" >0.805000</td>
#       <td id="T_2e3bc_row0_col2" class="data row0 col2" >0.522000</td>
#       <td id="T_2e3bc_row0_col3" class="data row0 col3" >0.610000</td>
#       <td id="T_2e3bc_row0_col4" class="data row0 col4" >0.562000</td>
#       <td id="T_2e3bc_row0_col5" class="data row0 col5" >0.848000</td>
#       <td id="T_2e3bc_row0_col6" class="data row0 col6" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_2e3bc_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_2e3bc_row1_col0" class="data row1 col0" >Stacking (SMOTE)</td>
#       <td id="T_2e3bc_row1_col1" class="data row1 col1" >0.803000</td>
#       <td id="T_2e3bc_row1_col2" class="data row1 col2" >0.547000</td>
#       <td id="T_2e3bc_row1_col3" class="data row1 col3" >0.593000</td>
#       <td id="T_2e3bc_row1_col4" class="data row1 col4" >0.569000</td>
#       <td id="T_2e3bc_row1_col5" class="data row1 col5" >0.856000</td>
#       <td id="T_2e3bc_row1_col6" class="data row1 col6" >0.278000</td>
#     </tr>
#     <tr>
#       <th id="T_2e3bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e3bc_row2_col0" class="data row2 col0" >Random Forest SMOTE</td>
#       <td id="T_2e3bc_row2_col1" class="data row2 col1" >0.784000</td>
#       <td id="T_2e3bc_row2_col2" class="data row2 col2" >0.517000</td>
#       <td id="T_2e3bc_row2_col3" class="data row2 col3" >0.508000</td>
#       <td id="T_2e3bc_row2_col4" class="data row2 col4" >0.513000</td>
#       <td id="T_2e3bc_row2_col5" class="data row2 col5" >0.845000</td>
#       <td id="T_2e3bc_row2_col6" class="data row2 col6" >0.359000</td>
#     </tr>
#     <tr>
#       <th id="T_2e3bc_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_2e3bc_row3_col0" class="data row3 col0" >Naive Bayes SMOTE</td>
#       <td id="T_2e3bc_row3_col1" class="data row3 col1" >0.774000</td>
#       <td id="T_2e3bc_row3_col2" class="data row3 col2" >0.443000</td>
#       <td id="T_2e3bc_row3_col3" class="data row3 col3" >0.593000</td>
#       <td id="T_2e3bc_row3_col4" class="data row3 col4" >0.507000</td>
#       <td id="T_2e3bc_row3_col5" class="data row3 col5" >0.815000</td>
#       <td id="T_2e3bc_row3_col6" class="data row3 col6" >0.716000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
from IPython.display import HTML

HTML('''
<style>
@import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');

/* Estilos de fondo y texto generales */
.conclusion-container {
    max-width: 900px;
    margin: 40px auto;
    background: linear-gradient(160deg, rgba(5,0,15,0.95), rgba(0, 0, 0, 0.9));
    border-radius: 20px;
    padding: 30px 40px;
    /* Borde neón pulsante */
    box-shadow: 0 0 25px #ff00aa80, 0 0 45px #00ff9980;
    border: 2px solid #00ff99;
    color: #f5f5f5;
    font-family: 'Poppins', sans-serif;
    line-height: 1.6;
}

/* Encabezado principal */
.conclusion-container h3 {
    text-align: center;
    font-size: 2.2em;
    font-family: 'Orbitron', sans-serif;
    color: #00ff99;
    text-shadow: 0 0 15px #00ff99aa, 0 0 20px #ff00aa80;
    margin-bottom: 25px;
    padding-bottom: 10px;
    border-bottom: 1px dashed rgba(255, 255, 255, 0.2);
}

/* Párrafo de justificación principal */
.justification {
    font-size: 1.1em;
    margin-top: 20px;
    border-left: 5px solid #ff00aa;
    padding-left: 15px;
    background: rgba(255, 0, 170, 0.08);
    border-radius: 5px;
    padding: 15px;
}

/* Resumen de métricas */
.metrics-section {
    margin-top: 30px;
    padding: 20px;
    border: 1px solid rgba(0, 255, 153, 0.4);
    border-radius: 10px;
    background: rgba(0, 0, 0, 0.5);
}

.metrics-section strong {
    color: #ff00aa;
    text-shadow: 0 0 5px #ff00aa;
    font-size: 1.1em;
}

/* Puntos de métricas */
.metrics-section ul {
    list-style-type: none;
    padding-left: 0;
}

.metrics-section li {
    margin-bottom: 10px;
    padding-left: 20px;
    position: relative;
}

.metrics-section li::before {
    content: "🔸";
    position: absolute;
    left: 0;
    color: #00ff99;
}

/* Resaltado de valores numéricos */
.highlight-value {
    color: #00ff99;
    font-weight: 700;
    text-shadow: 0 0 8px #00ff9980;
}

/* Énfasis en el costo del error */
.cost-emphasis {
    color: #ffb3e6;
    font-weight: bold;
    font-style: italic;
}
</style>

<div class="conclusion-container">
    <h3>👑 Gana el modelo Regresión Logística 👑</h3>

    <p>Probamos cuatro modelos y el modelo de <strong class="highlight-value">Regresión Logística (RL)</strong> fue el que mejores resultados mostró. Este logra el mejor AUC, lo que indica una mayor capacidad para distinguir entre empleados que rotan y los que no. El Stacking Classifier le sigue de cerca con un AUC de <span class="highlight-value">0.803</span>.</p>

    <div class="metrics-section">
        <strong>(F1 y Recall):</strong> El objetivo de identificar la rotación es crucial porque la clase de interés (empleado que se va [1]) es la minoritaria y la más costosa al fallar.

        <ul>
            <li>
                <strong>RL:</strong> Con un Recall de <span class="highlight-value">0.610</span>, este modelo es mejor para "atrapar" a los empleados que realmente rotarán. Es decir, tiene una tasa más baja de Falsos Negativos. Su enfoque está en no perderse casos de rotación, incluso si esto significa equivocarse un poco más a menudo (Precisión baja de 0.522).
            </li>
            <li>
                <strong>SC:</strong> Aunque su Recall es ligeramente menor (<span class="highlight-value">0.593</span>), su Precisión (0.547) es mejor. Esto significa que cuando este modelo predice que alguien rotará, es más probable que esa predicción sea correcta. Ofrece el F1-Score más alto (0.569) porque mejora la fiabilidad de las predicciones positivas, logrando un balance general óptimo.
            </li>
        </ul>
    </div>

    <hr style="border-top: 1px dashed rgba(255, 255, 255, 0.2); margin: 25px 0;">

    <p class="justification">
        Si bien el Stacking Classifier (SC) tuvo el F1-Score más alto (<span class="highlight-value">0.569</span>), mi conclusión es que la <strong class="highlight-value">Regresión Logística (RL)</strong> es el modelo más valioso para el objetivo de negocio.
    </p>

    <p class="justification">
        En el contexto de la rotación de empleados, el error más costoso es el <span class="cost-emphasis">Falso Negativo (FN)</span>. Un FN es cuando el modelo predice que un empleado se queda [0], pero en realidad se va [1]. Si fallamos en predecir que alguien de alto potencial se irá, <span class="cost-emphasis">perdemos la oportunidad de intervenir (ofrecer un aumento, un nuevo rol, etc.).</span>
    </p>
</div>
''')
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');
#
# /* Estilos de fondo y texto generales */
# .conclusion-container {
#     max-width: 900px;
#     margin: 40px auto;
#     background: linear-gradient(160deg, rgba(5,0,15,0.95), rgba(0, 0, 0, 0.9));
#     border-radius: 20px;
#     padding: 30px 40px;
#     /* Borde neón pulsante */
#     box-shadow: 0 0 25px #ff00aa80, 0 0 45px #00ff9980;
#     border: 2px solid #00ff99;
#     color: #f5f5f5;
#     font-family: 'Poppins', sans-serif;
#     line-height: 1.6;
# }
#
# /* Encabezado principal */
# .conclusion-container h3 {
#     text-align: center;
#     font-size: 2.2em;
#     font-family: 'Orbitron', sans-serif;
#     color: #00ff99;
#     text-shadow: 0 0 15px #00ff99aa, 0 0 20px #ff00aa80;
#     margin-bottom: 25px;
#     padding-bottom: 10px;
#     border-bottom: 1px dashed rgba(255, 255, 255, 0.2);
# }
#
# /* Párrafo de justificación principal */
# .justification {
#     font-size: 1.1em;
#     margin-top: 20px;
#     border-left: 5px solid #ff00aa;
#     padding-left: 15px;
#     background: rgba(255, 0, 170, 0.08);
#     border-radius: 5px;
#     padding: 15px;
# }
#
# /* Resumen de métricas */
# .metrics-section {
#     margin-top: 30px;
#     padding: 20px;
#     border: 1px solid rgba(0, 255, 153, 0.4);
#     border-radius: 10px;
#     background: rgba(0, 0, 0, 0.5);
# }
#
# .metrics-section strong {
#     color: #ff00aa;
#     text-shadow: 0 0 5px #ff00aa;
#     font-size: 1.1em;
# }
#
# /* Puntos de métricas */
# .metrics-section ul {
#     list-style-type: none;
#     padding-left: 0;
# }
#
# .metrics-section li {
#     margin-bottom: 10px;
#     padding-left: 20px;
#     position: relative;
# }
#
# .metrics-section li::before {
#     content: "🔸";
#     position: absolute;
#     left: 0;
#     color: #00ff99;
# }
#
# /* Resaltado de valores numéricos */
# .highlight-value {
#     color: #00ff99;
#     font-weight: 700;
#     text-shadow: 0 0 8px #00ff9980;
# }
#
# /* Énfasis en el costo del error */
# .cost-emphasis {
#     color: #ffb3e6;
#     font-weight: bold;
#     font-style: italic;
# }
# </style>
#
# <div class="conclusion-container">
#     <h3>👑 Gana el modelo Regresión Logística 👑</h3>
#
#     <p>Probamos cuatro modelos y el modelo de <strong class="highlight-value">Regresión Logística (RL)</strong> fue el que mejores resultados mostró. Este logra el mejor AUC, lo que indica una mayor capacidad para distinguir entre empleados que rotan y los que no. El Stacking Classifier le sigue de cerca con un AUC de <span class="highlight-value">0.803</span>.</p>
#
#     <div class="metrics-section">
#         <strong>(F1 y Recall):</strong> El objetivo de identificar la rotación es crucial porque la clase de interés (empleado que se va [1]) es la minoritaria y la más costosa al fallar.
#
#         <ul>
#             <li>
#                 <strong>RL:</strong> Con un Recall de <span class="highlight-value">0.610</span>, este modelo es mejor para "atrapar" a los empleados que realmente rotarán. Es decir, tiene una tasa más baja de Falsos Negativos. Su enfoque está en no perderse casos de rotación, incluso si esto significa equivocarse un poco más a menudo (Precisión baja de 0.522).
#             </li>
#             <li>
#                 <strong>SC:</strong> Aunque su Recall es ligeramente menor (<span class="highlight-value">0.593</span>), su Precisión (0.547) es mejor. Esto significa que cuando este modelo predice que alguien rotará, es más probable que esa predicción sea correcta. Ofrece el F1-Score más alto (0.569) porque mejora la fiabilidad de las predicciones positivas, logrando un balance general óptimo.
#             </li>
#         </ul>
#     </div>
#
#     <hr style="border-top: 1px dashed rgba(255, 255, 255, 0.2); margin: 25px 0;">
#
#     <p class="justification">
#         Si bien el Stacking Classifier (SC) tuvo el F1-Score más alto (<span class="highlight-value">0.569</span>), mi conclusión es que la <strong class="highlight-value">Regresión Logística (RL)</strong> es el modelo más valioso para el objetivo de negocio.
#     </p>
#
#     <p class="justification">
#         En el contexto de la rotación de empleados, el error más costoso es el <span class="cost-emphasis">Falso Negativo (FN)</span>. Un FN es cuando el modelo predice que un empleado se queda [0], pero en realidad se va [1]. Si fallamos en predecir que alguien de alto potencial se irá, <span class="cost-emphasis">perdemos la oportunidad de intervenir (ofrecer un aumento, un nuevo rol, etc.).</span>
#     </p>
# </div>

# %% [markdown]
# # **Monetizacion del modelo ganador💰**

# %%
#Definimos la matriz de Costos y Beneficios (C)
#Filas: Real (0, 1), Columnas: Predicción (0, 1)
C_costo=np.array([
    [0, -1000], # Fila 0 (Real=0): [VN=0, FP=-1000]
    [-10000, 9000] # Fila 1 (Real=1): [FN=-10000, VP=9000]
])

#Obtenemos los resultados
campeon_res=res_log

#Obtenemos las predicciones del modelo usando su Umbral F1 (0.640)
y_pred_campeon=(campeon_res['probs']>=campeon_res['thr']).astype(int)

# 3. Calcular la Matriz de Confusión (CM)
CM=confusion_matrix(y_test, y_pred_campeon)

# 4. Calcular el Impacto Económico Total (Ganancia)
ganancia_campeon=np.sum(CM * C_costo)

# 5. Calcular el Escenario Base (No acción / Predice siempre 0)
VN_base=CM[0, 0]+CM[0, 1]  # Total de Real=0
FN_base=CM[1, 0]+CM[1, 1]  # Total de Real=1

# Ganancia Base = (Total No Rotación * VN_costo) + (Total Rotación * FN_costo)
ganancia_base=(VN_base * C_costo[0, 0])+(FN_base * C_costo[1, 0])

VNC = ganancia_campeon - ganancia_base

print("\n--- Resultados de la Monetización ---")
print(f"Modelo Campeón: {campeon_res['nombre']}")
print(f"Matriz de Confusión (Regresión Logística) - Filas=Real, Col=Pred:\n{CM}")
print(f"Matriz de Costos ($C$) - Filas=Real, Col=Pred:\n{C_costo}")
print("\n--- Análisis Económico Final ---")
print(f"Ganancia del Modelo Campeón: ${ganancia_campeon:,.2f} USD")
print(f"Ganancia del Escenario Base (No acción): ${ganancia_base:,.2f} USD")
print(f"Valor Neto de la Clasificación (VNC): ${ganancia_campeon - ganancia_base:,.2f} USD")
# Out:
# --- Resultados de la Monetización ---
# Modelo Campeón: Regresión Logística SMOTE
# Matriz de Confusión (Regresión Logística) - Filas=Real, Col=Pred:
# [[276  33]
#  [ 23  36]]
# Matriz de Costos ($C$) - Filas=Real, Col=Pred:
# [[     0  -1000]
#  [-10000   9000]]
#
# --- Análisis Económico Final ---
# Ganancia del Modelo Campeón: $61,000.00 USD
# Ganancia del Escenario Base (No acción): $-590,000.00 USD
# Valor Neto de la Clasificación (VNC): $651,000.00 USD

# %%
# @title
# Datos Resultados de la Monetización
nombre_modelo = "Regresión Logística SMOTE"
CM_final = np.array([[276, 33], [23, 36]])
C_costo_final = np.array([[0, -1000], [-10000, 9000]])
ganancia_campeon_final = 61000.00
ganancia_base_final = -590000.00
vnc_final = 651000.00

# Formateo de las matrices para visualización HTML
CM_html = pd.DataFrame(CM_final, columns=['Predicción 0', 'Predicción 1'], index=['Real 0', 'Real 1']).to_html(classes='matrix-table', header=True, index=True)
Costo_html = pd.DataFrame(C_costo_final, columns=['Predicción 0', 'Predicción 1'], index=['Real 0', 'Real 1']).to_html(classes='matrix-table', header=True, index=True, float_format="${:,.0f}".format)


HTML_MONETIZATION = f'''
<style>
@import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');

.monet-card {{
    max-width: 900px;
    margin: 40px auto;
    background: linear-gradient(145deg, rgba(10, 0, 15, 0.95), rgba(0, 0, 0, 0.9));
    border-radius: 25px;
    padding: 30px;
    box-shadow: 0 0 20px #ff00aa80, 0 0 40px #00ff9980;
    border: 2px solid #ff00aa;
    color: #f5f5f5;
    font-family: 'Poppins', sans-serif;
}}

.monet-header {{
    text-align: center;
    font-size: 2.5em;
    font-family: 'Orbitron', sans-serif;
    color: #00ff99;
    text-shadow: 0 0 15px #00ff99aa, 0 0 20px #ff00aa80;
    margin-bottom: 10px;
    padding-bottom: 15px;
}}

.model-name {{
    text-align: center;
    font-size: 1.4em;
    color: #ffb3e6;
    margin-top: -10px;
    margin-bottom: 30px;
}}

/* Sección de Análisis Económico */
.economic-analysis {{
    border: 1px solid rgba(0, 255, 153, 0.4);
    border-radius: 15px;
    padding: 20px;
    background: rgba(0, 0, 0, 0.5);
    margin-top: 25px;
}}

.economic-analysis h4 {{
    text-align: center;
    color: #00ffcc;
    font-family: 'Orbitron', sans-serif;
    margin-top: 0;
}}

.metric-row {{
    display: flex;
    justify-content: space-between;
    padding: 10px 0;
    border-bottom: 1px dashed rgba(255, 255, 255, 0.1);
}}

.metric-row:last-child {{
    border-bottom: none;
    font-size: 1.2em;
    font-weight: bold;
}}

.metric-label {{
    color: #ff00aa;
}}

.metric-value {{
    color: #00ff99;
    font-weight: bold;
    text-shadow: 0 0 8px #00ff9980;
}}

/* Estilo para las tablas de Matriz */
.matrices-section {{
    display: flex;
    justify-content: space-around;
    gap: 20px;
    margin-top: 30px;
    text-align: center;
}}

.matrix-container {{
    flex-basis: 48%;
}}

.matrix-container h5 {{
    color: #ffb3e6;
    font-size: 1.1em;
    margin-bottom: 10px;
}}

.matrix-table {{
    width: 100%;
    border-collapse: collapse;
    background-color: rgba(10, 0, 20, 0.7);
}}

.matrix-table th, .matrix-table td {{
    padding: 10px;
    border: 1px solid rgba(0, 255, 153, 0.3);
    color: #f5f5f5;
}}

.matrix-table th {{
    background-color: rgba(255, 0, 170, 0.2);
    color: #00ff99;
}}
</style>

<div class="monet-card">
    <h1 class="monet-header">Monetización del Modelo Ganador 💰</h1>
    <h2 class="model-name">Modelo Campeón: {nombre_modelo}</h2>

    <div class="matrices-section">
        <div class="matrix-container">
            <h5>Matriz de Confusión (CM)</h5>
            {CM_html}
            <small style="color:#ffb3e6;">Filas: Real (0, 1), Columnas: Predicción (0, 1)</small>
        </div>

        <div class="matrix-container">
            <h5>Matriz de Costos ($C$)</h5>
            {Costo_html}
            <small style="color:#ffb3e6;">Valores: [VN=0, FP=-1000] / [FN=-10000, VP=9000]</small>
        </div>
    </div>

    <div class="economic-analysis">
        <h4>Análisis Económico Final</h4>

        <div class="metric-row">
            <span class="metric-label">Ganancia del Modelo Campeón:</span>
            <span class="metric-value">${ganancia_campeon_final:,.2f} USD</span>
        </div>

        <div class="metric-row">
            <span class="metric-label">Ganancia del Escenario Base (No Acción):</span>
            <span class="metric-value">${ganancia_base_final:,.2f} USD</span>
        </div>

        <div class="metric-row" style="border-top: 2px solid #00ff99; margin-top: 15px; padding-top: 15px;">
            <span class="metric-label">Valor Neto de la Clasificación (VNC):</span>
            <span class="metric-value">${vnc_final:,.2f} USD</span>
        </div>
    </div>
</div>
'''

display(HTML(HTML_MONETIZATION))
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');
#
# .monet-card {
#     max-width: 900px;
#     margin: 40px auto;
#     background: linear-gradient(145deg, rgba(10, 0, 15, 0.95), rgba(0, 0, 0, 0.9));
#     border-radius: 25px;
#     padding: 30px;
#     box-shadow: 0 0 20px #ff00aa80, 0 0 40px #00ff9980;
#     border: 2px solid #ff00aa;
#     color: #f5f5f5;
#     font-family: 'Poppins', sans-serif;
# }
#
# .monet-header {
#     text-align: center;
#     font-size: 2.5em;
#     font-family: 'Orbitron', sans-serif;
#     color: #00ff99;
#     text-shadow: 0 0 15px #00ff99aa, 0 0 20px #ff00aa80;
#     margin-bottom: 10px;
#     padding-bottom: 15px;
# }
#
# .model-name {
#     text-align: center;
#     font-size: 1.4em;
#     color: #ffb3e6;
#     margin-top: -10px;
#     margin-bottom: 30px;
# }
#
# /* Sección de Análisis Económico */
# .economic-analysis {
#     border: 1px solid rgba(0, 255, 153, 0.4);
#     border-radius: 15px;
#     padding: 20px;
#     background: rgba(0, 0, 0, 0.5);
#     margin-top: 25px;
# }
#
# .economic-analysis h4 {
#     text-align: center;
#     color: #00ffcc;
#     font-family: 'Orbitron', sans-serif;
#     margin-top: 0;
# }
#
# .metric-row {
#     display: flex;
#     justify-content: space-between;
#     padding: 10px 0;
#     border-bottom: 1px dashed rgba(255, 255, 255, 0.1);
# }
#
# .metric-row:last-child {
#     border-bottom: none;
#     font-size: 1.2em;
#     font-weight: bold;
# }
#
# .metric-label {
#     color: #ff00aa;
# }
#
# .metric-value {
#     color: #00ff99;
#     font-weight: bold;
#     text-shadow: 0 0 8px #00ff9980;
# }
#
# /* Estilo para las tablas de Matriz */
# .matrices-section {
#     display: flex;
#     justify-content: space-around;
#     gap: 20px;
#     margin-top: 30px;
#     text-align: center;
# }
#
# .matrix-container {
#     flex-basis: 48%;
# }
#
# .matrix-container h5 {
#     color: #ffb3e6;
#     font-size: 1.1em;
#     margin-bottom: 10px;
# }
#
# .matrix-table {
#     width: 100%;
#     border-collapse: collapse;
#     background-color: rgba(10, 0, 20, 0.7);
# }
#
# .matrix-table th, .matrix-table td {
#     padding: 10px;
#     border: 1px solid rgba(0, 255, 153, 0.3);
#     color: #f5f5f5;
# }
#
# .matrix-table th {
#     background-color: rgba(255, 0, 170, 0.2);
#     color: #00ff99;
# }
# </style>
#
# <div class="monet-card">
#     <h1 class="monet-header">Monetización del Modelo Ganador 💰</h1>
#     <h2 class="model-name">Modelo Campeón: Regresión Logística SMOTE</h2>
#
#     <div class="matrices-section">
#         <div class="matrix-container">
#             <h5>Matriz de Confusión (CM)</h5>
#             <table border="1" class="dataframe matrix-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predicción 0</th>
#       <th>Predicción 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Real 0</th>
#       <td>276</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>Real 1</th>
#       <td>23</td>
#       <td>36</td>
#     </tr>
#   </tbody>
# </table>
#             <small style="color:#ffb3e6;">Filas: Real (0, 1), Columnas: Predicción (0, 1)</small>
#         </div>
#
#         <div class="matrix-container">
#             <h5>Matriz de Costos ($C$)</h5>
#             <table border="1" class="dataframe matrix-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predicción 0</th>
#       <th>Predicción 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Real 0</th>
#       <td>0</td>
#       <td>-1000</td>
#     </tr>
#     <tr>
#       <th>Real 1</th>
#       <td>-10000</td>
#       <td>9000</td>
#     </tr>
#   </tbody>
# </table>
#             <small style="color:#ffb3e6;">Valores: [VN=0, FP=-1000] / [FN=-10000, VP=9000]</small>
#         </div>
#     </div>
#
#     <div class="economic-analysis">
#         <h4>Análisis Económico Final</h4>
#
#         <div class="metric-row">
#             <span class="metric-label">Ganancia del Modelo Campeón:</span>
#             <span class="metric-value">$61,000.00 USD</span>
#         </div>
#
#         <div class="metric-row">
#             <span class="metric-label">Ganancia del Escenario Base (No Acción):</span>
#             <span class="metric-value">$-590,000.00 USD</span>
#         </div>
#
#         <div class="metric-row" style="border-top: 2px solid #00ff99; margin-top: 15px; padding-top: 15px;">
#             <span class="metric-label">Valor Neto de la Clasificación (VNC):</span>
#             <span class="metric-value">$651,000.00 USD</span>
#         </div>
#     </div>
# </div>

# %%
# @title
from IPython.display import HTML

HTML('''
<style>
@import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');

/* Contenedor principal de la explicación */
.monet-expl-card {
    max-width: 900px;
    margin: 40px auto;
    background: linear-gradient(160deg, rgba(15, 0, 30, 0.95), rgba(0, 0, 0, 0.9));
    border-radius: 20px;
    padding: 30px 40px;
    box-shadow: 0 0 20px #00ff9980, 0 0 40px #ff00aa80;
    border: 2px solid #00ff99;
    color: #f5f5f5;
    font-family: 'Poppins', sans-serif;
    line-height: 1.6;
}

/* Título de la sección */
.monet-expl-card h3 {
    text-align: center;
    font-size: 2.2em;
    font-family: 'Orbitron', sans-serif;
    color: #ff00aa;
    text-shadow: 0 0 15px #ff00aa80, 0 0 20px #00ff9980;
    margin-bottom: 25px;
    padding-bottom: 10px;
    border-bottom: 1px dashed rgba(255, 255, 255, 0.2);
}

/* Subtítulos de pasos */
.monet-expl-card h4 {
    font-size: 1.4em;
    color: #00ff99;
    text-shadow: 0 0 5px #00ff9980;
    margin-top: 25px;
    border-left: 5px solid #ff00aa;
    padding-left: 10px;
}

/* Resaltado general */
.highlight-val {
    color: #00ffcc;
    font-weight: 700;
    text-shadow: 0 0 8px #00ffcc80;
}

/* Resaltado de dinero */
.money-gain {
    color: #00ff99;
    font-weight: 700;
    font-size: 1.1em;
    text-shadow: 0 0 8px #00ff99aa;
}

.money-loss {
    color: #ffb3e6;
    font-weight: 700;
    font-size: 1.1em;
}

/* Contenedor de la conclusión final */
.final-vnc {
    text-align: center;
    margin-top: 30px;
    padding: 25px;
    border: 2px solid #00ff99;
    border-radius: 15px;
    background: rgba(0, 0, 0, 0.6);
    box-shadow: 0 0 20px #00ff99aa;
}

.final-vnc p {
    font-size: 1.2em;
    margin: 10px 0;
}

.final-vnc .vnc-value {
    font-size: 2.5em;
    font-family: 'Orbitron', sans-serif;
    color: #ff00aa;
    text-shadow: 0 0 20px #ff00aa, 0 0 30px #00ff99;
    display: block;
    margin-top: 15px;
}
</style>

<div class="monet-expl-card">
    <h3>📈 Valoración Económica del Modelo de Rotación</h3>

    <h4>1. El Costo de Fallar (Foco en el FN)</h4>
    <p>Para la monetización, definimos la Matriz de Costos ($C$) enfocándonos en el error más costoso: el <strong class="highlight-val">Falso Negativo (FN)</strong>, donde el modelo dice que el empleado se queda [0], pero realmente rota [1].</p>
    <ul>
        <li>El costo de rotación (FN) fue valorado en <span class="money-loss">$-10,000 USD</span>.</li>
        <li>El beneficio de la retención exitosa (VP) es de <span class="money-gain">$+9,000 USD</span>.</li>
        <li>El costo de retener innecesariamente (FP) es de <span class="money-loss">$-1,000 USD</span>.</li>
    </ul>

    <h4>2. Ganancia del Modelo vs. Escenario Base</h4>
    <p>Contrastamos el resultado económico de usar la <strong class="highlight-val">Regresión Logística</strong> con el Escenario Base de **"no hacer nada"** (asumir que nadie rota).</p>

    <p>👉 **Ganancia del Escenario Base (No Acción):** <span class="money-loss">$-590,000.00 USD</span>.</p>
    <p style="padding-left: 20px; font-size: 0.95em;">— Este valor representa la pérdida inevitable de rotación si la empresa no interviniera (el costo de los FN que ocurren por no actuar).</p>

    <p>👉 **Ganancia del Modelo Campeón (Regresión Logística):** <span class="money-gain">$61,000.00 USD</span>.</p>
    <p style="padding-left: 20px; font-size: 0.95em;">— El modelo logra una ganancia neta positiva tras contabilizar todos los costos y beneficios de sus predicciones.</p>

    <hr style="border-top: 1px dashed rgba(255, 255, 255, 0.2); margin: 25px 0;">

    <div class="final-vnc">
        <p>El Valor Neto de la Clasificación (VNC) es la diferencia entre ambos, representando el valor económico **adicional** generado por el modelo:</p>

        <p class="vnc-value">VNC: $651,000.00 USD</p>

        <p style="font-style: italic; color: #ffb3e6;">
            <strong>Conclusión:</strong> La implementación del modelo es una inversión altamente rentable, generando <span class="money-gain">más de medio millón de dólares</span> en valor adicional frente a la inacción.
        </p>
    </div>
</div>
''')
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');
#
# /* Contenedor principal de la explicación */
# .monet-expl-card {
#     max-width: 900px;
#     margin: 40px auto;
#     background: linear-gradient(160deg, rgba(15, 0, 30, 0.95), rgba(0, 0, 0, 0.9));
#     border-radius: 20px;
#     padding: 30px 40px;
#     box-shadow: 0 0 20px #00ff9980, 0 0 40px #ff00aa80;
#     border: 2px solid #00ff99;
#     color: #f5f5f5;
#     font-family: 'Poppins', sans-serif;
#     line-height: 1.6;
# }
#
# /* Título de la sección */
# .monet-expl-card h3 {
#     text-align: center;
#     font-size: 2.2em;
#     font-family: 'Orbitron', sans-serif;
#     color: #ff00aa;
#     text-shadow: 0 0 15px #ff00aa80, 0 0 20px #00ff9980;
#     margin-bottom: 25px;
#     padding-bottom: 10px;
#     border-bottom: 1px dashed rgba(255, 255, 255, 0.2);
# }
#
# /* Subtítulos de pasos */
# .monet-expl-card h4 {
#     font-size: 1.4em;
#     color: #00ff99;
#     text-shadow: 0 0 5px #00ff9980;
#     margin-top: 25px;
#     border-left: 5px solid #ff00aa;
#     padding-left: 10px;
# }
#
# /* Resaltado general */
# .highlight-val {
#     color: #00ffcc;
#     font-weight: 700;
#     text-shadow: 0 0 8px #00ffcc80;
# }
#
# /* Resaltado de dinero */
# .money-gain {
#     color: #00ff99;
#     font-weight: 700;
#     font-size: 1.1em;
#     text-shadow: 0 0 8px #00ff99aa;
# }
#
# .money-loss {
#     color: #ffb3e6;
#     font-weight: 700;
#     font-size: 1.1em;
# }
#
# /* Contenedor de la conclusión final */
# .final-vnc {
#     text-align: center;
#     margin-top: 30px;
#     padding: 25px;
#     border: 2px solid #00ff99;
#     border-radius: 15px;
#     background: rgba(0, 0, 0, 0.6);
#     box-shadow: 0 0 20px #00ff99aa;
# }
#
# .final-vnc p {
#     font-size: 1.2em;
#     margin: 10px 0;
# }
#
# .final-vnc .vnc-value {
#     font-size: 2.5em;
#     font-family: 'Orbitron', sans-serif;
#     color: #ff00aa;
#     text-shadow: 0 0 20px #ff00aa, 0 0 30px #00ff99;
#     display: block;
#     margin-top: 15px;
# }
# </style>
#
# <div class="monet-expl-card">
#     <h3>📈 Valoración Económica del Modelo de Rotación</h3>
#
#     <h4>1. El Costo de Fallar (Foco en el FN)</h4>
#     <p>Para la monetización, definimos la Matriz de Costos ($C$) enfocándonos en el error más costoso: el <strong class="highlight-val">Falso Negativo (FN)</strong>, donde el modelo dice que el empleado se queda [0], pero realmente rota [1].</p>
#     <ul>
#         <li>El costo de rotación (FN) fue valorado en <span class="money-loss">$-10,000 USD</span>.</li>
#         <li>El beneficio de la retención exitosa (VP) es de <span class="money-gain">$+9,000 USD</span>.</li>
#         <li>El costo de retener innecesariamente (FP) es de <span class="money-loss">$-1,000 USD</span>.</li>
#     </ul>
#
#     <h4>2. Ganancia del Modelo vs. Escenario Base</h4>
#     <p>Contrastamos el resultado económico de usar la <strong class="highlight-val">Regresión Logística</strong> con el Escenario Base de **"no hacer nada"** (asumir que nadie rota).</p>
#
#     <p>👉 **Ganancia del Escenario Base (No Acción):** <span class="money-loss">$-590,000.00 USD</span>.</p>
#     <p style="padding-left: 20px; font-size: 0.95em;">— Este valor representa la pérdida inevitable de rotación si la empresa no interviniera (el costo de los FN que ocurren por no actuar).</p>
#
#     <p>👉 **Ganancia del Modelo Campeón (Regresión Logística):** <span class="money-gain">$61,000.00 USD</span>.</p>
#     <p style="padding-left: 20px; font-size: 0.95em;">— El modelo logra una ganancia neta positiva tras contabilizar todos los costos y beneficios de sus predicciones.</p>
#
#     <hr style="border-top: 1px dashed rgba(255, 255, 255, 0.2); margin: 25px 0;">
#
#     <div class="final-vnc">
#         <p>El Valor Neto de la Clasificación (VNC) es la diferencia entre ambos, representando el valor económico **adicional** generado por el modelo:</p>
#
#         <p class="vnc-value">VNC: $651,000.00 USD</p>
#
#         <p style="font-style: italic; color: #ffb3e6;">
#             <strong>Conclusión:</strong> La implementación del modelo es una inversión altamente rentable, generando <span class="money-gain">más de medio millón de dólares</span> en valor adicional frente a la inacción.
#         </p>
#     </div>
# </div>

# %%
# @title
from IPython.display import HTML

HTML('''
<style>
@import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');

/* Contenedor principal del Mapa de Flujo */
.flow-container {
    max-width: 950px;
    margin: 40px auto;
    background: radial-gradient(circle at center, #1a0033 0%, #000000 100%);
    border-radius: 25px;
    padding: 30px 20px;
    box-shadow: 0 0 30px #00ff9980;
    font-family: 'Poppins', sans-serif;
    color: #f5f5f5;
    display: flex;
    flex-direction: column;
    align-items: center;
}

.flow-header {
    font-size: 2.4em;
    font-family: 'Orbitron', sans-serif;
    color: #ff00aa;
    text-shadow: 0 0 15px #ff00aa80, 0 0 20px #00ff9980;
    margin-bottom: 30px;
    text-align: center;
}

/* Estilo para cada paso (Nodo) */
.flow-node {
    width: 90%;
    margin: 15px 0;
    padding: 20px;
    border-radius: 12px;
    text-align: center;
    position: relative;
    transition: transform 0.3s, box-shadow 0.3s;
}

.flow-node:hover {
    transform: translateY(-5px);
    box-shadow: 0 8px 20px rgba(255, 255, 255, 0.1);
}

.flow-node h4 {
    font-family: 'Orbitron', sans-serif;
    margin-top: 0;
    font-size: 1.3em;
}

/* Estilo de la flecha/línea de conexión */
.flow-arrow {
    width: 2px;
    height: 30px;
    background: linear-gradient(to bottom, #00ff99, #ff00aa);
    box-shadow: 0 0 10px #00ff99;
    margin: 5px 0;
}

/* Estilos Específicos para el Contenido */

/* 1. Punto de Partida: Escenario Base */
.node-start {
    background: rgba(255, 0, 170, 0.2);
    border: 2px solid #ff00aa;
    box-shadow: 0 0 15px #ff00aa;
}
.node-start h4 {
    color: #ffb3e6;
}
.node-start .value {
    color: #ffb3e6;
    font-weight: 700;
    font-size: 1.2em;
}

/* 2. El Impacto de la Clasificación */
.node-process {
    background: rgba(0, 0, 0, 0.6);
    border: 2px solid #00ff99;
}
.node-process h4 {
    color: #00ff99;
}
.node-process strong {
    color: #ff00aa;
}

/* 3. Ganancia Bruta del Modelo */
.node-result {
    background: rgba(0, 255, 153, 0.2);
    border: 2px solid #00ff99;
    box-shadow: 0 0 15px #00ff99;
}
.node-result h4 {
    color: #00ffcc;
}
.node-result .value {
    color: #00ff99;
    font-weight: 700;
    font-size: 1.2em;
}

/* 4. Conclusión Final (VNC) */
.node-final {
    background: linear-gradient(135deg, #00ff99, #ff00aa);
    color: #000;
    padding: 30px;
    border: 3px solid #f5f5f5;
    box-shadow: 0 0 30px #ff00aa, 0 0 50px #00ff99;
}
.node-final h4 {
    color: #1a0033;
    font-size: 1.5em;
    text-shadow: none;
}
.node-final .vnc-value {
    font-size: 3em;
    font-family: 'Orbitron', sans-serif;
    color: #1a0033;
    text-shadow: 0 0 5px #f5f5f5;
    display: block;
}
</style>

<div class="flow-container">
    <h1 class="flow-header">Mapa de Flujo de la Monetización</h1>

    <div class="flow-node node-start">
        <h4>Paso 1: Punto de Partida (Inacción)</h4>
        <p>El Escenario Base representa el costo de la rotación que ocurre cuando <strong>no se usa el modelo</strong> (asumir Predicción 0).</p>
        <p>Ganancia del Escenario Base: <span class="value">$-590,000.00 USD</span></p>
    </div>

    <div class="flow-arrow"></div>

    <div class="flow-node node-process">
        <h4>Paso 2: La Clasificación Activa (Modelo RL)</h4>
        <p>El modelo interviene, generando <strong>Verdaderos Positivos</strong> (Beneficio de $9k) y <strong>Falsos Negativos</strong> (Costo de $10k), y <strong>Falsos Positivos</strong> (Costo de $1k).</p>
        <p>El objetivo es maximizar VP y minimizar FN.</p>
    </div>

    <div class="flow-arrow"></div>

    <div class="flow-node node-result">
        <h4>Paso 3: Ganancia Total del Modelo Campeón</h4>
        <p>Es la suma de todos los beneficios y costos generados por las predicciones del modelo.</p>
        <p>Ganancia del Modelo Campeón: <span class="value">$61,000.00 USD</span></p>
    </div>

    <div class="flow-arrow" style="height: 40px;"></div>

    <div class="flow-node node-final">
        <h4>Paso 4: Valor Neto de la Clasificación (VNC)</h4>
        <p>El VNC mide la ganancia <strong>adicional</strong> de usar el modelo, comparado con la inacción. (Ganancia Modelo - Ganancia Base).</p>
        <p class="vnc-value">$651,000.00 USD</p>
        <p style="color: #1a0033; font-weight: 700;">El modelo es una inversión altamente rentable que genera este valor adicional.</p>
    </div>
</div>
''')
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');
#
# /* Contenedor principal del Mapa de Flujo */
# .flow-container {
#     max-width: 950px;
#     margin: 40px auto;
#     background: radial-gradient(circle at center, #1a0033 0%, #000000 100%);
#     border-radius: 25px;
#     padding: 30px 20px;
#     box-shadow: 0 0 30px #00ff9980;
#     font-family: 'Poppins', sans-serif;
#     color: #f5f5f5;
#     display: flex;
#     flex-direction: column;
#     align-items: center;
# }
#
# .flow-header {
#     font-size: 2.4em;
#     font-family: 'Orbitron', sans-serif;
#     color: #ff00aa;
#     text-shadow: 0 0 15px #ff00aa80, 0 0 20px #00ff9980;
#     margin-bottom: 30px;
#     text-align: center;
# }
#
# /* Estilo para cada paso (Nodo) */
# .flow-node {
#     width: 90%;
#     margin: 15px 0;
#     padding: 20px;
#     border-radius: 12px;
#     text-align: center;
#     position: relative;
#     transition: transform 0.3s, box-shadow 0.3s;
# }
#
# .flow-node:hover {
#     transform: translateY(-5px);
#     box-shadow: 0 8px 20px rgba(255, 255, 255, 0.1);
# }
#
# .flow-node h4 {
#     font-family: 'Orbitron', sans-serif;
#     margin-top: 0;
#     font-size: 1.3em;
# }
#
# /* Estilo de la flecha/línea de conexión */
# .flow-arrow {
#     width: 2px;
#     height: 30px;
#     background: linear-gradient(to bottom, #00ff99, #ff00aa);
#     box-shadow: 0 0 10px #00ff99;
#     margin: 5px 0;
# }
#
# /* Estilos Específicos para el Contenido */
#
# /* 1. Punto de Partida: Escenario Base */
# .node-start {
#     background: rgba(255, 0, 170, 0.2);
#     border: 2px solid #ff00aa;
#     box-shadow: 0 0 15px #ff00aa;
# }
# .node-start h4 {
#     color: #ffb3e6;
# }
# .node-start .value {
#     color: #ffb3e6;
#     font-weight: 700;
#     font-size: 1.2em;
# }
#
# /* 2. El Impacto de la Clasificación */
# .node-process {
#     background: rgba(0, 0, 0, 0.6);
#     border: 2px solid #00ff99;
# }
# .node-process h4 {
#     color: #00ff99;
# }
# .node-process strong {
#     color: #ff00aa;
# }
#
# /* 3. Ganancia Bruta del Modelo */
# .node-result {
#     background: rgba(0, 255, 153, 0.2);
#     border: 2px solid #00ff99;
#     box-shadow: 0 0 15px #00ff99;
# }
# .node-result h4 {
#     color: #00ffcc;
# }
# .node-result .value {
#     color: #00ff99;
#     font-weight: 700;
#     font-size: 1.2em;
# }
#
# /* 4. Conclusión Final (VNC) */
# .node-final {
#     background: linear-gradient(135deg, #00ff99, #ff00aa);
#     color: #000;
#     padding: 30px;
#     border: 3px solid #f5f5f5;
#     box-shadow: 0 0 30px #ff00aa, 0 0 50px #00ff99;
# }
# .node-final h4 {
#     color: #1a0033;
#     font-size: 1.5em;
#     text-shadow: none;
# }
# .node-final .vnc-value {
#     font-size: 3em;
#     font-family: 'Orbitron', sans-serif;
#     color: #1a0033;
#     text-shadow: 0 0 5px #f5f5f5;
#     display: block;
# }
# </style>
#
# <div class="flow-container">
#     <h1 class="flow-header">Mapa de Flujo de la Monetización</h1>
#
#     <div class="flow-node node-start">
#         <h4>Paso 1: Punto de Partida (Inacción)</h4>
#         <p>El Escenario Base representa el costo de la rotación que ocurre cuando <strong>no se usa el modelo</strong> (asumir Predicción 0).</p>
#         <p>Ganancia del Escenario Base: <span class="value">$-590,000.00 USD</span></p>
#     </div>
#
#     <div class="flow-arrow"></div>
#
#     <div class="flow-node node-process">
#         <h4>Paso 2: La Clasificación Activa (Modelo RL)</h4>
#         <p>El modelo interviene, generando <strong>Verdaderos Positivos</strong> (Beneficio de $9k) y <strong>Falsos Negativos</strong> (Costo de $10k), y <strong>Falsos Positivos</strong> (Costo de $1k).</p>
#         <p>El objetivo es maximizar VP y minimizar FN.</p>
#     </div>
#
#     <div class="flow-arrow"></div>
#
#     <div class="flow-node node-result">
#         <h4>Paso 3: Ganancia Total del Modelo Campeón</h4>
#         <p>Es la suma de todos los beneficios y costos generados por las predicciones del modelo.</p>
#         <p>Ganancia del Modelo Campeón: <span class="value">$61,000.00 USD</span></p>
#     </div>
#
#     <div class="flow-arrow" style="height: 40px;"></div>
#
#     <div class="flow-node node-final">
#         <h4>Paso 4: Valor Neto de la Clasificación (VNC)</h4>
#         <p>El VNC mide la ganancia <strong>adicional</strong> de usar el modelo, comparado con la inacción. (Ganancia Modelo - Ganancia Base).</p>
#         <p class="vnc-value">$651,000.00 USD</p>
#         <p style="color: #1a0033; font-weight: 700;">El modelo es una inversión altamente rentable que genera este valor adicional.</p>
#     </div>
# </div>

# %%
# @title
from IPython.display import HTML

HTML('''
<style>
@import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');

.thanks-container {
    max-width: 800px;
    margin: 60px auto 40px auto;
    background: rgba(0, 0, 0, 0.8);
    border-radius: 15px;
    padding: 30px;
    text-align: center;
    border: 3px solid #ff00aa; /* Borde principal */
    box-shadow: 0 0 25px #00ff9980, 0 0 45px #ff00aa80;
    color: #f5f5f5;
    font-family: 'Poppins', sans-serif;
}

.thanks-container h3 {
    font-size: 2.5em;
    font-family: 'Orbitron', sans-serif;
    color: #00ff99;
    text-shadow: 0 0 10px #00ff99, 0 0 15px #ff00aa;
    margin-bottom: 15px;
    letter-spacing: 2px;
}

.thanks-container p {
    font-size: 1.1em;
    color: #ffb3e6;
    margin-top: 20px;
}

.thanks-container .signature {
    margin-top: 30px;
    font-size: 1.2em;
    color: #00ffcc;
    font-weight: 700;
}
</style>

<div class="thanks-container">
    <h3>¡GRACIAS POR SU TIEMPO! 🚀</h3>
    <p>Esperamos que el análisis de desbalance de clases, el desarrollo de modelos y la monetización del Valor Neto de la Clasificación (VNC) hayan demostrado el potencial de este proyecto.</p>
    <p>Valoramos mucho la oportunidad de presentarle nuestro trabajo.</p>
    <div class="signature">
        FIN DEL PROYECTO
    </div>
</div>
''')
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700&family=Poppins:wght@300;500&display=swap');
#
# .thanks-container {
#     max-width: 800px;
#     margin: 60px auto 40px auto;
#     background: rgba(0, 0, 0, 0.8);
#     border-radius: 15px;
#     padding: 30px;
#     text-align: center;
#     border: 3px solid #ff00aa; /* Borde principal */
#     box-shadow: 0 0 25px #00ff9980, 0 0 45px #ff00aa80;
#     color: #f5f5f5;
#     font-family: 'Poppins', sans-serif;
# }
#
# .thanks-container h3 {
#     font-size: 2.5em;
#     font-family: 'Orbitron', sans-serif;
#     color: #00ff99;
#     text-shadow: 0 0 10px #00ff99, 0 0 15px #ff00aa;
#     margin-bottom: 15px;
#     letter-spacing: 2px;
# }
#
# .thanks-container p {
#     font-size: 1.1em;
#     color: #ffb3e6;
#     margin-top: 20px;
# }
#
# .thanks-container .signature {
#     margin-top: 30px;
#     font-size: 1.2em;
#     color: #00ffcc;
#     font-weight: 700;
# }
# </style>
#
# <div class="thanks-container">
#     <h3>¡GRACIAS POR SU TIEMPO! 🚀</h3>
#     <p>Esperamos que el análisis de desbalance de clases, el desarrollo de modelos y la monetización del Valor Neto de la Clasificación (VNC) hayan demostrado el potencial de este proyecto.</p>
#     <p>Valoramos mucho la oportunidad de presentarle nuestro trabajo.</p>
#     <div class="signature">
#         FIN DEL PROYECTO
#     </div>
# </div>
